# %% [markdown]
# # Violation of Baccari et al.'s Bell inequality for star graphs from size 2 to 57 on IBM Quantum Brooklyn

# %%
import sys
import time
import numpy as np
import pickle

# %%
max_size = 57
max_length = 56

# %%
with open("./pkls/raw_hist_list.pkl", "rb") as f:
    raw_hist_list = pickle.load(f)
with open("./pkls/ignis_hist_list.pkl", "rb") as f:
    ignis_hist_list = pickle.load(f)
with open("./pkls/delta_hist_list.pkl", "rb") as f:
    delta_hist_list = pickle.load(f)
with open("./pkls/lnp_hist_list.pkl", "rb") as f:
    lnp_hist_list = pickle.load(f)
with open("./pkls/mooney01_hist_list.pkl", "rb") as f:
    mooney01_hist_list = pickle.load(f)
with open("./pkls/nation_hist_list.pkl", "rb") as f:
    nation_hist_list = pickle.load(f)

# %%
sys.path.append("../../libs_bell/")
from lib_graph_states import adjacency_list_for_star_graph, list_to_matrix
F_list = [3 * i + 1 for i in range(max_size // 3)] # subset of focused vertices of graph size max_size
Fs = [F_list[:(n+1) // 3] for n in range(1, max_size + 1)] # subsets of focused vertices of graph size 1 to max_size
adj_lists = [adjacency_list_for_star_graph(n) for n in range(1, max_size + 1)] # adjacency list of graph size 1 to max_size
graphs = [list_to_matrix(adj_list) for adj_list in adj_lists] # adjacency matrix of graph size 1 to max_size
print("max_size:", max_size)
print("F_list:", F_list)
# Out:
# max_size: 57
# F_list: [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55]

# %%
from lib_star_graphs import correlations_of_star_graphs

# %%
corr_list, stddev_list, Es_list, Ds_list = correlations_of_star_graphs(adj_lists, Fs, raw_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.4658967925948843
#
# graph size: 3
# total correlation: 4.5796212625285
#
# graph size: 4
# total correlation: 5.3837696627233935
#
# graph size: 5
# total correlation: 7.0410295843443675
#
# graph size: 6
# total correlation: 9.292515580495479
#
# graph size: 7
# total correlation: 10.081225115931282
#
# graph size: 8
# total correlation: 11.657249147071
#
# graph size: 9
# total correlation: 13.746459661211526
#
# graph size: 10
# total correlation: 14.755281980166133
#
# graph size: 11
# total correlation: 16.27864771454265
#
# graph size: 12
# total correlation: 18.61541465549507
#
# graph size: 13
# total correlation: 19.457127754677074
#
# graph size: 14
# total correlation: 20.98947043061162
#
# graph size: 15
# total correlation: 23.325201570615036
#
# graph size: 16
# total correlation: 24.222105335457222
#
# graph size: 17
# total correlation: 25.84944848333713
#
# graph size: 18
# total correlation: 27.887904750976475
#
# graph size: 19
# total correlation: 28.862604877062964
#
# graph size: 20
# total correlation: 30.13766441221258
#
# graph size: 21
# total correlation: 32.339777229794514
#
# graph size: 22
# total correlation: 33.12896785965133
#
# graph size: 23
# total correlation: 34.85159453112856
#
# graph size: 24
# total correlation: 37.31024071708042
#
# graph size: 25
# total correlation: 37.952145359462705
#
# graph size: 26
# total correlation: 39.52720001493141
#
# graph size: 27
# total correlation: 41.49142388122549
#
# graph size: 28
# total correlation: 42.310164457353416
#
# graph size: 29
# total correlation: 44.095772734003866
#
# graph size: 30
# total correlation: 46.09107062876806
#
# graph size: 31
# total correlation: 47.43879913388085
#
# graph size: 32
# total correlation: 48.56698016386998
#
# graph size: 33
# total correlation: 50.73076834633877
#
# graph size: 34
# total correlation: 51.63427407176698
#
# graph size: 35
# total correlation: 53.41418333822444
#
# graph size: 36
# total correlation: 55.44297213033975
#
# graph size: 37
# total correlation: 56.555946601262725
#
# graph size: 38
# total correlation: 57.504561285840175
#
# graph size: 39
# total correlation: 59.49260857396134
#
# graph size: 40
# total correlation: 60.30834585048229
#
# graph size: 41
# total correlation: 62.299974412744454
#
# graph size: 42
# total correlation: 64.23001684772142
#
# graph size: 43
# total correlation: 65.12876542437661
#
# graph size: 44
# total correlation: 66.29851134288187
#
# graph size: 45
# total correlation: 68.69570000585949
#
# graph size: 46
# total correlation: 69.44034103119813
#
# graph size: 47
# total correlation: 70.79699486440506
#
# graph size: 48
# total correlation: 73.57915621342909
#
# graph size: 49
# total correlation: 73.75420363322672
#
# graph size: 50
# total correlation: 75.69840495509072
#
# graph size: 51
# total correlation: 77.61670831264564
#
# graph size: 52
# total correlation: 78.78756197298583
#
# graph size: 53
# total correlation: 80.22589090318604
#
# graph size: 54
# total correlation: 82.89998368653067
#
# graph size: 55
# total correlation: 83.6381585787213
#
# graph size: 56
# total correlation: 84.82035864598359

# %%
ignis_corr_list, ignis_stddev_list, ignis_Es_list, ignis_Ds_list = correlations_of_star_graphs(adj_lists, Fs, ignis_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.7419985427639655
#
# graph size: 3
# total correlation: 5.19329085459756
#
# graph size: 4
# total correlation: 5.92204402047396
#
# graph size: 5
# total correlation: 7.823282406596273
#
# graph size: 6
# total correlation: 10.82542559867331
#
# graph size: 7
# total correlation: 11.58769260423604
#
# graph size: 8
# total correlation: 13.075050343140012
#
# graph size: 9
# total correlation: 15.989141642129026

# %%
delta_corr_list, delta_stddev_list, delta_Es_list, delta_Ds_list = correlations_of_star_graphs(adj_lists, Fs, delta_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.7421815383619115
#
# graph size: 3
# total correlation: 5.193380155350603
#
# graph size: 4
# total correlation: 5.927179828183758
#
# graph size: 5
# total correlation: 7.82954815311365
#
# graph size: 6
# total correlation: 10.827047411604559
#
# graph size: 7
# total correlation: 11.590924160904908
#
# graph size: 8
# total correlation: 13.071971207037588
#
# graph size: 9
# total correlation: 15.991562927124418
#
# graph size: 10
# total correlation: 17.089136544750513
#
# graph size: 11
# total correlation: 18.466844960630254
#
# graph size: 12
# total correlation: 21.04883509249894
#
# graph size: 13
# total correlation: 22.23023157115815
#
# graph size: 14
# total correlation: 23.69884697693285
#
# graph size: 15
# total correlation: 26.38765705897768
#
# graph size: 16
# total correlation: 27.41588651081561
#
# graph size: 17
# total correlation: 28.764524549898397
#
# graph size: 18
# total correlation: 31.201638767962955
#
# graph size: 19
# total correlation: 31.72577611226438
#
# graph size: 20
# total correlation: 33.06712878511185
#
# graph size: 21
# total correlation: 34.74304137685937
#
# graph size: 22
# total correlation: 35.048280647430865
#
# graph size: 23
# total correlation: 36.40911817811739
#
# graph size: 24
# total correlation: 38.56275834638936
#
# graph size: 25
# total correlation: 38.81441007027605
#
# graph size: 26
# total correlation: 40.28289740092642
#
# graph size: 27
# total correlation: 42.11562358376205
#
# graph size: 28
# total correlation: 42.60798185830513
#
# graph size: 29
# total correlation: 44.3362941321874
#
# graph size: 30
# total correlation: 46.34957723836741
#
# graph size: 31
# total correlation: 47.64182262848623
#
# graph size: 32
# total correlation: 48.68697597511743
#
# graph size: 33
# total correlation: 50.86267492735307
#
# graph size: 34
# total correlation: 51.75135215865906
#
# graph size: 35
# total correlation: 53.62862930074823
#
# graph size: 36
# total correlation: 55.5418593547467
#
# graph size: 37
# total correlation: 56.65777144605273
#
# graph size: 38
# total correlation: 57.65375813172991
#
# graph size: 39
# total correlation: 59.50441478654067
#
# graph size: 40
# total correlation: 60.59067879700871
#
# graph size: 41
# total correlation: 62.264404618823335
#
# graph size: 42
# total correlation: 64.33629946889674
#
# graph size: 43
# total correlation: 65.17717419149373
#
# graph size: 44
# total correlation: 66.4520789518905
#
# graph size: 45
# total correlation: 68.69467959789249
#
# graph size: 46
# total correlation: 69.6630786400581
#
# graph size: 47
# total correlation: 71.06079298856577
#
# graph size: 48
# total correlation: 73.7434747819588
#
# graph size: 49
# total correlation: 73.88667868358809
#
# graph size: 50
# total correlation: 76.0942353588692
#
# graph size: 51
# total correlation: 77.77185565742903
#
# graph size: 52
# total correlation: 79.196973868702
#
# graph size: 53
# total correlation: 80.35290187240813
#
# graph size: 54
# total correlation: 83.32278585303733
#
# graph size: 55
# total correlation: 83.62850348463475
#
# graph size: 56
# total correlation: 85.08371728009571

# %%
lnp_corr_list, lnp_stddev_list, lnp_Es_list, lnp_Ds_list = correlations_of_star_graphs(adj_lists, Fs, lnp_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.7421815383619115
#
# graph size: 3
# total correlation: 5.193380155350603
#
# graph size: 4
# total correlation: 5.927179828183757
#
# graph size: 5
# total correlation: 7.829548153113651
#
# graph size: 6
# total correlation: 10.827095957908934
#
# graph size: 7
# total correlation: 11.59065920859387
#
# graph size: 8
# total correlation: 13.072222245601107
#
# graph size: 9
# total correlation: 15.995154363185733
#
# graph size: 10
# total correlation: 17.092078534180708
#
# graph size: 11
# total correlation: 18.47050484866469
#
# graph size: 12
# total correlation: 21.04888700285788
#
# graph size: 13
# total correlation: 22.23931641570373
#
# graph size: 14
# total correlation: 23.707940280565815
#
# graph size: 15
# total correlation: 26.380796668874474
#
# graph size: 16
# total correlation: 27.42065274674359
#
# graph size: 17
# total correlation: 28.76619732666295
#
# graph size: 18
# total correlation: 31.20315871512984
#
# graph size: 19
# total correlation: 31.72734092768184
#
# graph size: 20
# total correlation: 33.064890864503376
#
# graph size: 21
# total correlation: 34.744408925552904
#
# graph size: 22
# total correlation: 35.048043429876
#
# graph size: 23
# total correlation: 36.409606429243745
#
# graph size: 24
# total correlation: 38.56283344093029
#
# graph size: 25
# total correlation: 38.81439725296737
#
# graph size: 26
# total correlation: 40.28283954072529
#
# graph size: 27
# total correlation: 42.11559335552015
#
# graph size: 28
# total correlation: 42.60798601238376
#
# graph size: 29
# total correlation: 44.336306863583594
#
# graph size: 30
# total correlation: 46.34958657539127
#
# graph size: 31
# total correlation: 47.64182694408872
#
# graph size: 32
# total correlation: 48.686974703753116
#
# graph size: 33
# total correlation: 50.86267593277663
#
# graph size: 34
# total correlation: 51.75135318313074
#
# graph size: 35
# total correlation: 53.62863007066048
#
# graph size: 36
# total correlation: 55.54186020968605
#
# graph size: 37
# total correlation: 56.657771616326045
#
# graph size: 38
# total correlation: 57.653758186397944
#
# graph size: 39
# total correlation: 59.504414818910924
#
# graph size: 40
# total correlation: 60.590678831067216
#
# graph size: 41
# total correlation: 62.26440462101603
#
# graph size: 42
# total correlation: 64.33629948167257
#
# graph size: 43
# total correlation: 65.17717419389518
#
# graph size: 44
# total correlation: 66.45207895443329
#
# graph size: 45
# total correlation: 68.69467959811772
#
# graph size: 46
# total correlation: 69.66307864052555
#
# graph size: 47
# total correlation: 71.06079298870637
#
# graph size: 48
# total correlation: 73.7434747819817
#
# graph size: 49
# total correlation: 73.88667868367659
#
# graph size: 50
# total correlation: 76.0942353588704
#
# graph size: 51
# total correlation: 77.77185565781147
#
# graph size: 52
# total correlation: 79.19697386870149
#
# graph size: 53
# total correlation: 80.35290187247033
#
# graph size: 54
# total correlation: 83.32278585303402
#
# graph size: 55
# total correlation: 83.62850348461988
#
# graph size: 56
# total correlation: 85.08371728009726

# %%
mooney01_corr_list, mooney01_stddev_list, mooney01_Es_list, mooney01_Ds_list = correlations_of_star_graphs(adj_lists, Fs, mooney01_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.8284271247461903
#
# graph size: 3
# total correlation: 5.656854249492381
#
# graph size: 4
# total correlation: 6.656854249492381
#
# graph size: 5
# total correlation: 8.485281374238571
#
# graph size: 6
# total correlation: 11.313708498984761
#
# graph size: 7
# total correlation: nan
#
# graph size: 8
# total correlation: nan
#
# graph size: 9
# total correlation: nan
#
# graph size: 10
# total correlation: nan
#
# graph size: 11
# total correlation: nan
#
# graph size: 12
# total correlation: nan
#
# graph size: 13
# total correlation: nan
#
# graph size: 14
# total correlation: nan
#
# graph size: 15
# total correlation: nan
#
# graph size: 16
# total correlation: nan
#
# graph size: 17
# total correlation: nan
#
# graph size: 18
# total correlation: nan
#
# graph size: 19
# total correlation: nan
#
# graph size: 20
# total correlation: nan
#
# graph size: 21
# total correlation: nan
#
# graph size: 22
# total correlation: nan
#
# graph size: 23
# total correlation: nan
#
# graph size: 24
# total correlation: nan
#
# graph size: 25
# total correlation: nan
#
# graph size: 26
# total correlation: nan
#
# graph size: 27
# total correlation: nan
#
# graph size: 28
# total correlation: nan
#
# graph size: 29
# total correlation: nan
# /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/mitigation/expval/utils.py:87: RuntimeWarning: invalid value encountered in true_divide
#   probs = probs / shots

# %%
nation_corr_list, nation_stddev_list, nation_Es_list, nation_Ds_list = correlations_of_star_graphs(adj_lists, Fs, nation_hist_list)
# Out:
# Encountered a negative variance in expectation value calculation.(-0.054524). Setting standard deviation of result to 0.
# Encountered a negative variance in expectation value calculation.(-0.005326). Setting standard deviation of result to 0.
# graph size: 1
# skipped
#
# graph size: 2
# total correlation: 2.7446650897159297
#
# graph size: 3
# total correlation: 5.193132717901264
#
# graph size: 4
# total correlation: 5.963439656506868
#
# graph size: 5
# total correlation: 7.808094874503153
#
# graph size: 6
# total correlation: 10.826330889874852
#
# graph size: 7
# total correlation: 11.685408940622969
#
# graph size: 8
# total correlation: 13.12241414575702
#
# graph size: 9
# total correlation: 15.895312285445849
#
# graph size: 10
# total correlation: 16.983112538496027
#
# graph size: 11
# total correlation: 18.16510639192634
#
# graph size: 12
# total correlation: 20.408942296497358
#
# graph size: 13
# total correlation: 21.39156917870947
#
# graph size: 14
# total correlation: 22.73273580406025
#
# graph size: 15
# total correlation: 25.025933475066868
#
# graph size: 16
# total correlation: 25.667889490084185
#
# graph size: 17
# total correlation: 26.93821113425244
#
# graph size: 18
# total correlation: 28.83460645252922
#
# graph size: 19
# total correlation: 29.452554243861087
#
# graph size: 20
# total correlation: 30.692869174435778
#
# graph size: 21
# total correlation: 32.6624339597125
#
# graph size: 22
# total correlation: 33.30772343005049
#
# graph size: 23
# total correlation: 34.958316271579314
#
# graph size: 24
# total correlation: 37.371131539216734
#
# graph size: 25
# total correlation: 37.98655365521642
#
# graph size: 26
# total correlation: 39.565597044745104
#
# graph size: 27
# total correlation: 41.515522717454274
#
# graph size: 28
# total correlation: 42.32126927274537
#
# graph size: 29
# total correlation: 44.10106008264372

# %% [markdown]
# ## plot correlations

# %%
c_bounds = [0] + [n + (n // 3) for n in range(2, max_size + 1)]
q_bounds = [0]
for n in range(2, max_size + 1):
    q_bounds.append( 2 * (np.sqrt(2) * 2 - 1) * (n // 3) + n - ((n + 1) // 3))
    if (n + 1) % 3 == 0:
        q_bounds[-1] += (np.sqrt(2) * 2 - 1)

# %%
from lib_plots import plot_correlations_lines, cut_corrs_list

# %%
corrs_list = [np.array(corr_list), 
              np.array(ignis_corr_list),
              np.array(delta_corr_list),
              np.array(lnp_corr_list),
              np.array(mooney01_corr_list),
              np.array(nation_corr_list)]
stddevs_list = [np.array(stddev_list),
                np.array(ignis_stddev_list),
                np.array(delta_stddev_list),
                np.array(lnp_stddev_list),
                np.array(mooney01_stddev_list),
                np.array(nation_stddev_list)]

# %%
plot_correlations_lines(max_size, 
                        c_bounds, 
                        q_bounds, 
                        corrs_list,
                        stddevs_list,
                        ["raw", 
                         "mitigated (ignis)", 
                         "mitigated (proposed, delta)", 
                         "mitigated (proposed, least norm)", 
                         "mitigated (Mooney et al., threshold = 0.1)",
                         "mitigated (Nation et al., iterative)"], 
                        # ["*", "*", "*", "*", "*", "*"], 
                        "Correlation of Star Graphs (ibmq_brooklyn)")

# %%
plot_correlations_lines(15,
                        c_bounds[:15],
                        q_bounds[:15],
                        cut_corrs_list(corrs_list, 15),
                        cut_corrs_list(stddevs_list, 15),
                        ["raw", 
                         "mitigated (ignis)", 
                         "mitigated (proposed, delta)", 
                         "mitigated (proposed, least norm)", 
                         "mitigated (Mooney et al., threshold = 0.1)",
                         "mitigated (Nation et al., iterative)"], 
                        # ["*", "*", "*", "*", "*", "*"], 
                        "Correlation of Star Graphs (ibmq_brooklyn)")

# %%
with open("./pkls/corrs_stddevs_list.pkl", "wb") as f:
    pickle.dump([corrs_list, stddevs_list], f)
