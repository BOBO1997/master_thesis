# %% [markdown]
# # Violation of Baccari et al.'s Bell inequality for star graphs from size 2 to 57 on IBM Quantum manhattan

# %%
import sys
import time
import numpy as np
import pickle

# %%
max_size = 39
max_length = 38

# %%
with open("./pkls/raw_hist_list.pkl", "rb") as f:
    raw_hist_list = pickle.load(f)
# with open("./pkls/ignis_hist_list.pkl", "rb") as f:
#     ignis_hist_list = pickle.load(f)
# with open("./pkls/delta_hist_list.pkl", "rb") as f:
#     delta_hist_list = pickle.load(f)
with open("./pkls/lnp_hist_list.pkl", "rb") as f:
    lnp_hist_list = pickle.load(f)
# with open("./pkls/mooney01_hist_list.pkl", "rb") as f:
#     mooney01_hist_list = pickle.load(f)
# with open("./pkls/nation_hist_list.pkl", "rb") as f:
#     nation_hist_list = pickle.load(f)

# %%
sys.path.append("../../libs_bell/")
from lib_graph_states import adjacency_list_for_star_graph, list_to_matrix
F_list = [3 * i + 1 for i in range(max_size // 3)] # subset of focused vertices of graph size max_size
Fs = [F_list[:(n+1) // 3] for n in range(1, max_size + 1)] # subsets of focused vertices of graph size 1 to max_size
adj_lists = [adjacency_list_for_star_graph(n) for n in range(1, max_size + 1)] # adjacency list of graph size 1 to max_size
graphs = [list_to_matrix(adj_list) for adj_list in adj_lists] # adjacency matrix of graph size 1 to max_size
print("max_size:", max_size)
print("F_list:", F_list)
# Out:
# max_size: 39
# F_list: [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37]

# %%
from lib_star_graphs import correlations_of_star_graphs

# %%
corr_list, stddev_list, Es_list, Ds_list = correlations_of_star_graphs(adj_lists, raw_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# first term
# second term
# total correlation: 2.5825970328493044
#
# graph size: 3
# first term
# second term
# total correlation: 4.8402978346944385
#
# graph size: 4
# first term
# second term
# total correlation: 6.963689780152089
#
# graph size: 5
# first term
# second term
# total correlation: 8.916865102990126
#
# graph size: 6
# first term
# second term
# total correlation: 10.916306201550329
#
# graph size: 7
# first term
# second term
# total correlation: 11.972823169534136
#
# graph size: 8
# first term
# second term
# total correlation: 12.223832266176041
#
# graph size: 9
# first term
# second term
# total correlation: 12.7396611387799
#
# graph size: 10
# first term
# second term
# total correlation: 13.20369996393357
#
# graph size: 11
# first term
# second term
# total correlation: 14.534358916420365
#
# graph size: 12
# first term
# second term
# total correlation: 14.153529434169993
#
# graph size: 13
# first term
# second term
# total correlation: 11.125537993249083
#
# graph size: 14
# first term
# second term
# total correlation: 10.235439711071876
#
# graph size: 15
# first term
# second term
# total correlation: 11.451124758219256
#
# graph size: 16
# first term
# second term
# total correlation: 11.92414052493096
#
# graph size: 17
# first term
# second term
# total correlation: 11.587159949521746
#
# graph size: 18
# first term
# second term
# total correlation: 13.53964473839378
#
# graph size: 19
# first term
# second term
# total correlation: 16.81760947500759
#
# graph size: 20
# first term
# second term
# total correlation: 22.38745644478366
#
# graph size: 21
# first term
# second term
# total correlation: 23.113552910035274
#
# graph size: 22
# first term
# second term
# total correlation: 24.874414523341617
#
# graph size: 23
# first term
# second term
# total correlation: 25.858080157912163
#
# graph size: 24
# first term
# second term
# total correlation: 30.21500421640486
#
# graph size: 25
# first term
# second term
# total correlation: 28.951672325603308
#
# graph size: 26
# first term
# second term
# total correlation: 27.805731209022177
#
# graph size: 27
# first term
# second term
# total correlation: 26.904584383388933
#
# graph size: 28
# first term
# second term
# total correlation: 26.541708784254624
#
# graph size: 29
# first term
# second term
# total correlation: 27.827483028951256
#
# graph size: 30
# first term
# second term
# total correlation: 28.201061904558603
#
# graph size: 31
# first term
# second term
# total correlation: 30.222600090030888
#
# graph size: 32
# first term
# second term
# total correlation: 29.57177182707354
#
# graph size: 33
# first term
# second term
# total correlation: 30.435284551559654
#
# graph size: 34
# first term
# second term
# total correlation: 33.91212307038218
#
# graph size: 35
# first term
# second term
# total correlation: 36.40356961971916
#
# graph size: 36
# first term
# second term
# total correlation: 38.271809264738884
#
# graph size: 37
# first term
# second term
# total correlation: 38.89605197000513
#
# graph size: 38
# first term
# second term
# total correlation: 39.964998549376986
#
# graph size: 39
# first term
# second term
# total correlation: 40.78776976986895

# %%
# ignis_corr_list, ignis_stddev_list, ignis_Es_list, ignis_Ds_list = correlations_of_star_graphs(adj_lists, ignis_hist_list)

# %%
# delta_corr_list, delta_stddev_list, delta_Es_list, delta_Ds_list = correlations_of_star_graphs(adj_lists, delta_hist_list)

# %%
lnp_corr_list, lnp_stddev_list, lnp_Es_list, lnp_Ds_list = correlations_of_star_graphs(adj_lists, lnp_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# first term
# second term
# total correlation: 2.7986056377509
#
# graph size: 3
# first term
# second term
# total correlation: 5.556423028128341
#
# graph size: 4
# first term
# second term
# total correlation: 8.406390392561851
#
# graph size: 5
# first term
# second term
# total correlation: 10.942092772516672
#
# graph size: 6
# first term
# second term
# total correlation: 13.778523648895701
#
# graph size: 7
# first term
# second term
# total correlation: 15.693570638923148
#
# graph size: 8
# first term
# second term
# total correlation: 16.588691424011976
#
# graph size: 9
# first term
# second term
# total correlation: 16.871971026054023
#
# graph size: 10
# first term
# second term
# total correlation: 17.315059155399997
#
# graph size: 11
# first term
# second term
# total correlation: 18.749961201890358
#
# graph size: 12
# first term
# second term
# total correlation: 17.11696870396012
#
# graph size: 13
# first term
# second term
# total correlation: 11.164878760139409
#
# graph size: 14
# first term
# second term
# total correlation: 10.364958738363935
#
# graph size: 15
# first term
# second term
# total correlation: 12.401703708153843
#
# graph size: 16
# first term
# second term
# total correlation: 13.444939585430575
#
# graph size: 17
# first term
# second term
# total correlation: 13.853412784495264
#
# graph size: 18
# first term
# second term
# total correlation: 16.27625161605101
#
# graph size: 19
# first term
# second term
# total correlation: 19.926861623247735
#
# graph size: 20
# first term
# second term
# total correlation: 25.944134893580724
#
# graph size: 21
# first term
# second term
# total correlation: 26.77396937048187
#
# graph size: 22
# first term
# second term
# total correlation: 28.70730804472241
#
# graph size: 23
# first term
# second term
# total correlation: 29.78771811017499
#
# graph size: 24
# first term
# second term
# total correlation: 34.670600405058785
#
# graph size: 25
# first term
# second term
# total correlation: 33.61862406298606
#
# graph size: 26
# first term
# second term
# total correlation: 32.00491968095635
#
# graph size: 27
# first term
# second term
# total correlation: 31.775281636965346
#
# graph size: 28
# first term
# second term
# total correlation: 31.56293603074776
#
# graph size: 29
# first term
# second term
# total correlation: 33.20194266465589
#
# graph size: 30
# first term
# second term
# total correlation: 33.87147118584572
#
# graph size: 31
# first term
# second term
# total correlation: 36.246661894709206
#
# graph size: 32
# first term
# second term
# total correlation: 35.26431886188686
#
# graph size: 33
# first term
# second term
# total correlation: 36.589252328974545
#
# graph size: 34
# first term
# second term
# total correlation: 40.34092918837478
#
# graph size: 35
# first term
# second term
# total correlation: 43.6312745668039
#
# graph size: 36
# first term
# second term
# total correlation: 45.11548119295767
#
# graph size: 37
# first term
# second term
# total correlation: 47.82101364401873
#
# graph size: 38
# first term
# second term
# total correlation: 48.34933662012244
#
# graph size: 39
# first term
# second term
# total correlation: 49.396828074786335

# %%
# mooney01_corr_list, mooney01_stddev_list, mooney01_Es_list, mooney01_Ds_list = correlations_of_star_graphs(adj_lists, mooney01_hist_list)

# %%
# nation_corr_list, nation_stddev_list, nation_Es_list, nation_Ds_list = correlations_of_star_graphs(adj_lists, nation_hist_list)

# %% [markdown]
# ## plot correlations

# %%
c_bounds = [2 * i for i in range(max_size)]
q_bounds = [2 * np.sqrt(2) * i for i in range(max_size)]

# %%
from lib_plots import plot_correlations_lines, cut_corrs_list

# %%
corrs_list = [np.array(corr_list), 
              # np.array(ignis_corr_list),
              # np.array(delta_corr_list),
              np.array(lnp_corr_list),
              # np.array(mooney01_corr_list),
              # np.array(nation_corr_list),
             ]
stddevs_list = [np.array(stddev_list),
                # np.array(ignis_stddev_list),
                # np.array(delta_stddev_list),
                np.array(lnp_stddev_list),
                # np.array(mooney01_stddev_list),
                # np.array(nation_stddev_list),
               ]

# %%
plot_correlations_lines(max_size, 
                        c_bounds, 
                        q_bounds, 
                        corrs_list,
                        stddevs_list,
                        ["raw", 
                         # "mitigated (ignis)", 
                         # "mitigated (proposed, delta)", 
                         "mitigated (proposed, least norm)", 
                         # "mitigated (Mooney et al., threshold = 0.1)",
                         # "mitigated (Nation et al., iterative)",
                        ], 
                        # ["*", "*", "*", "*", "*", "*"], 
                        "Correlation of Star Graphs (ibmq_manhattan)")

# %%
with open("./pkls/corrs_stddevs_list.pkl", "wb") as f:
    pickle.dump([corrs_list, stddevs_list], f)

# %%
each_corr_list = [[0]] + [E_1 + Es_2 for E_1, Es_2 in Es_list[1:]]
tp_each_corr_list = []
for i in range(len(each_corr_list)):
    tp_each_corr_list.append([each_corr_list[j][i] for j in range(i, len(each_corr_list))])
# pprint.pprint(tp_each_corr_list)

# %%
each_stddev_list = [[0]] + [D_1 + Ds_2 for D_1, Ds_2 in Ds_list[1:]]
tp_each_stddev_list = []
for i in range(len(each_stddev_list)):
    tp_each_stddev_list.append([each_stddev_list[j][i] for j in range(i, len(each_stddev_list))])
# pprint.pprint(tp_each_corr_list)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.clf()
for i, (each_corr, each_stddev) in enumerate(zip(tp_each_corr_list, tp_each_stddev_list)):
    if i == 0:
        plt.plot(list(range(2, max_size + 1)), each_corr[1:], color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))])
        plt.errorbar(list(range(2, max_size + 1)), each_corr[1:], label=str(i), color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))], fmt="x", yerr=each_stddev[1:], capsize=3)
    else:
        plt.plot(list(range(i+1, max_size + 1)), each_corr, color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))])
        plt.errorbar(list(range(i+1, max_size + 1)), each_corr, label=str(i), color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))], fmt="v", yerr=each_stddev, capsize=3)
#  plt.plot(list(range(1, max_size + 1)), damped_vibration, label="damped vibration", color=[0, 0, 1])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlabel("graph size")
plt.ylabel("correlation")
plt.xticks(list(range(max_size + 2)))
plt.ylim([-1,1])
plt.title("correlation of each term (ibmq_manhattan)")
plt.show()
