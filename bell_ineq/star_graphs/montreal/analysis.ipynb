# %%
import sys
import time
import numpy as np
import pickle

# %%
max_size = 27
max_length = 26

# %%
with open("./pkls/raw_hist_list.pkl", "rb") as f:
    raw_hist_list = pickle.load(f)
# with open("./pkls/ignis_hist_list.pkl", "rb") as f:
#     ignis_hist_list = pickle.load(f)
# with open("./pkls/delta_hist_list.pkl", "rb") as f:
#     delta_hist_list = pickle.load(f)
with open("./pkls/lnp_hist_list.pkl", "rb") as f:
    lnp_hist_list = pickle.load(f)
# with open("./pkls/mooney01_hist_list.pkl", "rb") as f:
#     mooney01_hist_list = pickle.load(f)
# with open("./pkls/nation_hist_list.pkl", "rb") as f:
#     nation_hist_list = pickle.load(f)

# %%
sys.path.append("../../libs_bell/")
from lib_graph_states import adjacency_list_for_star_graph, list_to_matrix
F_list = [3 * i + 1 for i in range(max_size // 3)] # subset of focused vertices of graph size max_size
Fs = [F_list[:(n+1) // 3] for n in range(1, max_size + 1)] # subsets of focused vertices of graph size 1 to max_size
adj_lists = [adjacency_list_for_star_graph(n) for n in range(1, max_size + 1)] # adjacency list of graph size 1 to max_size
graphs = [list_to_matrix(adj_list) for adj_list in adj_lists] # adjacency matrix of graph size 1 to max_size
print("max_size:", max_size)
print("F_list:", F_list)
# Out:
# max_size: 27
# F_list: [1, 4, 7, 10, 13, 16, 19, 22, 25]

# %%
from lib_star_graphs import correlations_of_star_graphs

# %%
corr_list, stddev_list, Es_list, Ds_list = correlations_of_star_graphs(adj_lists, raw_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# first term
# second term
# total correlation: 2.4928276172689814
#
# graph size: 3
# first term
# second term
# total correlation: 4.877931935841574
#
# graph size: 4
# first term
# second term
# total correlation: 7.101451306369585
#
# graph size: 5
# first term
# second term
# total correlation: 8.954844471120262
#
# graph size: 6
# first term
# second term
# total correlation: 11.061318334410851
#
# graph size: 7
# first term
# second term
# total correlation: 13.032447540364954
#
# graph size: 8
# first term
# second term
# total correlation: 13.2396077301657
#
# graph size: 9
# first term
# second term
# total correlation: 14.423528214876965
#
# graph size: 10
# first term
# second term
# total correlation: 16.400181692559087
#
# graph size: 11
# first term
# second term
# total correlation: 11.871314676531771
#
# graph size: 12
# first term
# second term
# total correlation: 13.13153916448631
#
# graph size: 13
# first term
# second term
# total correlation: 16.5987102077848
#
# graph size: 14
# first term
# second term
# total correlation: 12.679239416754681
#
# graph size: 15
# first term
# second term
# total correlation: 12.553216967959226
#
# graph size: 16
# first term
# second term
# total correlation: 10.178815925859672
#
# graph size: 17
# first term
# second term
# total correlation: 13.875589512853992
#
# graph size: 18
# first term
# second term
# total correlation: 13.510297044838675
#
# graph size: 19
# first term
# second term
# total correlation: 14.535049450386367
#
# graph size: 20
# first term
# second term
# total correlation: 15.122693855454484
#
# graph size: 21
# first term
# second term
# total correlation: 13.62250881431408
#
# graph size: 22
# first term
# second term
# total correlation: 20.674241675131487
#
# graph size: 23
# first term
# second term
# total correlation: 24.862675445919574
#
# graph size: 24
# first term
# second term
# total correlation: 22.694398792671763
#
# graph size: 25
# first term
# second term
# total correlation: 23.050023785163045
#
# graph size: 26
# first term
# second term
# total correlation: 26.25133925155058
#
# graph size: 27
# first term
# second term
# total correlation: 22.436484356369835

# %%
# ignis_corr_list, ignis_stddev_list, ignis_Es_list, ignis_Ds_list = correlations_of_star_graphs(adj_lists, ignis_hist_list)

# %%
# delta_corr_list, delta_stddev_list, delta_Es_list, delta_Ds_list = correlations_of_star_graphs(adj_lists, delta_hist_list)

# %%
lnp_corr_list, lnp_stddev_list, lnp_Es_list, lnp_Ds_list = correlations_of_star_graphs(adj_lists, lnp_hist_list)
# Out:
# graph size: 1
# skipped
#
# graph size: 2
# first term
# second term
# total correlation: 2.7784874838931097
#
# graph size: 3
# first term
# second term
# total correlation: 5.500039860995133
#
# graph size: 4
# first term
# second term
# total correlation: 8.2053381434446
#
# graph size: 5
# first term
# second term
# total correlation: 10.6661357326991
#
# graph size: 6
# first term
# second term
# total correlation: 13.364212746742554
#
# graph size: 7
# first term
# second term
# total correlation: 15.859558066859812
#
# graph size: 8
# first term
# second term
# total correlation: 16.272618841859984
#
# graph size: 9
# first term
# second term
# total correlation: 18.555346142285966
#
# graph size: 10
# first term
# second term
# total correlation: 21.026136999503755
#
# graph size: 11
# first term
# second term
# total correlation: 13.961370724514602
#
# graph size: 12
# first term
# second term
# total correlation: 15.691720897300737
#
# graph size: 13
# first term
# second term
# total correlation: 19.512967576553987
#
# graph size: 14
# first term
# second term
# total correlation: 13.990333463707488
#
# graph size: 15
# first term
# second term
# total correlation: 13.776376589701217
#
# graph size: 16
# first term
# second term
# total correlation: 12.284340613152319
#
# graph size: 17
# first term
# second term
# total correlation: 15.753532954512695
#
# graph size: 18
# first term
# second term
# total correlation: 16.218538758389926
#
# graph size: 19
# first term
# second term
# total correlation: 17.407963590939563
#
# graph size: 20
# first term
# second term
# total correlation: 19.282261677126513
#
# graph size: 21
# first term
# second term
# total correlation: 17.207138551345704
#
# graph size: 22
# first term
# second term
# total correlation: 24.047620651644806
#
# graph size: 23
# first term
# second term
# total correlation: 28.13511649959918
#
# graph size: 24
# first term
# second term
# total correlation: 28.077884279680497
#
# graph size: 25
# first term
# second term
# total correlation: 27.27196833238717
#
# graph size: 26
# first term
# second term
# total correlation: 30.370786669723003
#
# graph size: 27
# first term
# second term
# total correlation: 28.10470694422652

# %%
# mooney01_corr_list, mooney01_stddev_list, mooney01_Es_list, mooney01_Ds_list = correlations_of_star_graphs(adj_lists, mooney01_hist_list)

# %%
# nation_corr_list, nation_stddev_list, nation_Es_list, nation_Ds_list = correlations_of_star_graphs(adj_lists, nation_hist_list)

# %% [markdown]
# ## plot correlations

# %%
c_bounds = [2 * i for i in range(max_size)]
q_bounds = [2 * np.sqrt(2) * i for i in range(max_size)]

# %%
from lib_plots import plot_correlations_lines, cut_corrs_list

# %%
corrs_list = [np.array(corr_list), 
              # np.array(ignis_corr_list),
              # np.array(delta_corr_list),
              np.array(lnp_corr_list),
              # np.array(mooney01_corr_list),
              # np.array(nation_corr_list),
             ]
stddevs_list = [np.array(stddev_list),
                # np.array(ignis_stddev_list),
                # np.array(delta_stddev_list),
                np.array(lnp_stddev_list),
                # np.array(mooney01_stddev_list),
                # np.array(nation_stddev_list),
               ]

# %%
plot_correlations_lines(max_size, 
                        c_bounds, 
                        q_bounds, 
                        corrs_list,
                        stddevs_list,
                        ["raw", 
                         # "mitigated (ignis)", 
                         # "mitigated (proposed, delta)", 
                         "mitigated (proposed, least norm)", 
                         # "mitigated (Mooney et al., threshold = 0.1)",
                         # "mitigated (Nation et al., iterative)",
                        ], 
                        # ["*", "*", "*", "*", "*", "*"], 
                        "Correlation of Star Graphs (ibmq_montreal)")

# %%
with open("./pkls/corrs_stddevs_list.pkl", "wb") as f:
    pickle.dump([corrs_list, stddevs_list], f)

# %%
each_corr_list = [[0]] + [E_1 + Es_2 for E_1, Es_2 in Es_list[1:]]
tp_each_corr_list = []
for i in range(len(each_corr_list)):
    tp_each_corr_list.append([each_corr_list[j][i] for j in range(i, len(each_corr_list))])
# pprint.pprint(tp_each_corr_list)

# %%
each_stddev_list = [[0]] + [D_1 + Ds_2 for D_1, Ds_2 in Ds_list[1:]]
tp_each_stddev_list = []
for i in range(len(each_stddev_list)):
    tp_each_stddev_list.append([each_stddev_list[j][i] for j in range(i, len(each_stddev_list))])
# pprint.pprint(tp_each_corr_list)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.clf()
for i, (each_corr, each_stddev) in enumerate(zip(tp_each_corr_list, tp_each_stddev_list)):
    if i == 0:
        plt.plot(list(range(2, max_size + 1)), each_corr[1:], color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))])
        plt.errorbar(list(range(2, max_size + 1)), each_corr[1:], label=str(i), color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))], fmt="x", yerr=each_stddev[1:], capsize=3)
    else:
        plt.plot(list(range(i+1, max_size + 1)), each_corr, color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))])
        plt.errorbar(list(range(i+1, max_size + 1)), each_corr, label=str(i), color=[min(1, 2*i/max_size), 0, min(1, 2*(1-i/max_size))], fmt="v", yerr=each_stddev, capsize=3)
#  plt.plot(list(range(1, max_size + 1)), damped_vibration, label="damped vibration", color=[0, 0, 1])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlabel("graph size")
plt.ylabel("correlation")
plt.xticks(list(range(max_size + 2)))
plt.ylim([-1,1])
plt.title("correlation of each term (ibmq_montreal)")
plt.show()
