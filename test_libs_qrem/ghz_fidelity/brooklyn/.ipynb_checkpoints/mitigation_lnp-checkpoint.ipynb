# %%
import pickle
import time
import gc

# %%
max_size = 65

# %%
from libs_qrem import LeastNormFilter
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
def get_info(mitigator):
    return {"exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
def results_to_info(n):
    print("start", n, "qubits")
    lnp_ghz_mqc_info = {}

    with open("pkls/raw_results/results_" + str(n) + "-qubit.pkl", "rb") as f:
        results = pickle.load(f)
        f.close()

    mitigator = LeastNormFilter(n, TensoredMeasFitter(results["mit"], mit_pattern=[[j] for j in range(n)]).cal_matrices)
    _ = mitigator.apply(results["ghz"].get_counts())
    lnp_ghz_mqc_info["ghz"] = get_info(mitigator)
    print("mitigated ghz hist")
    
    lnp_ghz_mqc_info["mqc"] = []
    for i, mqc_hist in enumerate( results["mqc"].get_counts() ):
        _ = mitigator.apply(mqc_hist)
        # print(i + 1, "th mqc")
        lnp_ghz_mqc_info["mqc"].append( get_info(mitigator) )
    print("mitigated mqc hists")

    with open("pkls/lnp/info_" + str(n) + "-qubit.pkl", "wb") as f:
        pickle.dump(lnp_ghz_mqc_info, f)
        f.close()

    print("finished", n, "qubits")
    print()
    del lnp_ghz_mqc_info, results, mitigator
    gc.collect()

# %%
for n in range(1, max_size + 1):
    results_to_info(n)
# Out:
# start 1 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 1 qubits
#
# start 2 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 2 qubits
#
# start 3 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 3 qubits
#
# start 4 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 4 qubits
#
# start 5 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 5 qubits
#
# start 6 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 6 qubits
#
# start 7 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 7 qubits
#
# start 8 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 8 qubits
#
# start 9 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 9 qubits
#
# start 10 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 10 qubits
#
# start 11 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 11 qubits
#
# start 12 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 12 qubits
#
# start 13 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 13 qubits
#
# start 14 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 14 qubits
#
# start 15 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 15 qubits
#
# start 16 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 16 qubits
#
# start 17 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 17 qubits
#
# start 18 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 18 qubits
#
# start 19 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 19 qubits
#
# start 20 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 20 qubits
#
# start 21 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 21 qubits
#
# start 22 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 22 qubits
#
# start 23 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 23 qubits
#
# start 24 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 24 qubits
#
# start 25 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 25 qubits
#
# start 26 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 26 qubits
#
# start 27 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 27 qubits
#
# start 28 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 28 qubits
#
# start 29 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 29 qubits
#
# start 30 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 30 qubits
#
# start 31 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 31 qubits
#
# start 32 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 32 qubits
#
# start 33 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 33 qubits
#
# start 34 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 34 qubits
#
# start 35 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 35 qubits
#
# start 36 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 36 qubits
#
# start 37 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 37 qubits
#
# start 38 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 38 qubits
#
# start 39 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 39 qubits
#
# start 40 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 40 qubits
#
# start 41 qubits
# mitigated ghz hist
# mitigated mqc hists
# finished 41 qubits
#
# start 42 qubits
# mitigated ghz hist
