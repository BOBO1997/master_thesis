# %%
import sys
sys.path.append('../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np
import time

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from libs_qrem import IgnisFilter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_14790/4108104578.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 30

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/meas_fitter_list_list.pkl", "rb") as f:
    meas_fitter_list_list = pickle.load(f)

# %%
ignis_mitigator_list_list = []
for num_qubits in range(min_size, 25 + 1):
    t1 = time.perf_counter()
    ignis_mitigator_list = []
    for i in range(0, max_iter):
        ignis_mitigator_list.append(IgnisFilter(num_qubits, meas_fitter_list_list[num_qubits - 1][i].cal_matrices))
        if i % 10 == 0:
            print("iter", i, "finished")
    ignis_mitigator_list_list.append(ignis_mitigator_list)
    t2 = time.perf_counter()
    print("length of ignis_mitigator_list: ", len(ignis_mitigator_list))
    print("size", num_qubits, "finished (t=", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 1 finished (t= 0.002784949000002257 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 2 finished (t= 0.0003056410000041865 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 3 finished (t= 0.0007915529999991122 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 4 finished (t= 0.0004429649999977414 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 5 finished (t= 0.0005304929999994101 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 6 finished (t= 0.0006532079999956864 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 7 finished (t= 0.0007102949999975294 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 8 finished (t= 0.0007859659999951418 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 9 finished (t= 0.0012333780000020056 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 10 finished (t= 0.0009669890000054693 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 11 finished (t= 0.0011003290000033417 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 12 finished (t= 0.0011870959999953357 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 13 finished (t= 0.0012547050000009108 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 14 finished (t= 0.0013037050000050954 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 15 finished (t= 0.0015064059999971846 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 16 finished (t= 0.0014953539999993382 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 17 finished (t= 0.0016701260000004936 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 18 finished (t= 0.0016165309999962574 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 19 finished (t= 0.0017980260000030057 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 20 finished (t= 0.002012256000000434 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 21 finished (t= 0.0020868250000063426 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 22 finished (t= 0.0022227659999956018 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 23 finished (t= 0.002236046999996688 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 24 finished (t= 0.002203356000002543 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 25 finished (t= 0.0026772980000018265 s)

# %%
def get_info(mitigator):
    return {"exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
ignis_info_list_list = []
ignis_hist_list_list = []
for i in range(min_size - 1, 25):
    t1 = time.perf_counter()
    ignis_info_list = []
    ignis_hist_list = []
    for j in range(0, max_iter):
        ignis_hist_list.append( ignis_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
        ignis_info_list.append( get_info(ignis_mitigator_list_list[i][j]) )
        print("iter", j, "finished")
    ignis_hist_list_list.append( ignis_hist_list )
    ignis_info_list_list.append( ignis_info_list )
    t2 = time.perf_counter()
    print("size", i + 1, "finished (t=", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 1 finished (t= 0.001644575000000259 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 2 finished (t= 0.01616120599999249 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 3 finished (t= 0.0010657149999957483 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 4 finished (t= 0.0015344939999977214 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 5 finished (t= 0.0008583940000050916 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 6 finished (t= 0.0016377720000093632 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 7 finished (t= 0.0014458980000000565 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 8 finished (t= 0.0021146090000030426 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 9 finished (t= 0.003271132999998372 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 10 finished (t= 0.004905965000006063 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 11 finished (t= 0.009571781999994755 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 12 finished (t= 0.015981266000011374 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 13 finished (t= 0.030322091999991585 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 14 finished (t= 0.07689045400000794 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 15 finished (t= 0.12916286199998694 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 16 finished (t= 0.26874093199998583 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 17 finished (t= 0.5819091989999947 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 18 finished (t= 1.1722887359999987 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 19 finished (t= 2.7124076730000013 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 20 finished (t= 6.059270256000005 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 21 finished (t= 13.302069876000004 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 22 finished (t= 28.506434772999995 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 23 finished (t= 65.984117081 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 24 finished (t= 265.84060429199997 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 25 finished (t= 673.497653868 s)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_14790/3975542505.py in <module>
#       6     ignis_hist_list = []
#       7     for j in range(0, max_iter):
# ----> 8         ignis_hist_list.append( ignis_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
#       9         ignis_info_list.append( get_info(ignis_mitigator_list_list[i][j]) )
#      10         print("iter", j, "finished")
#
# IndexError: list index out of range

# %%
with open("pkls/ignis_info_list_list.pkl", "wb") as f:
    pickle.dump(ignis_info_list_list, f)
with open("pkls/ignis_hist_list_list.pkl", "wb") as f:
    pickle.dump(ignis_hist_list_list, f)
