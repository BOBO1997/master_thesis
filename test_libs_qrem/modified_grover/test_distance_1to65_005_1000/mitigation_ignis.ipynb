# %%
import sys
sys.path.append('../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np
import time

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from libs_qrem import IgnisFilter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_15609/4108104578.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 25

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/cal_matrices_list_list.pkl", "rb") as f:
    cal_matrices_list_list = pickle.load(f)

# %%
ignis_mitigator_list_list = []
for num_qubits in range(min_size, 25 + 1):
    t1 = time.perf_counter()
    ignis_mitigator_list = []
    for i in range(0, max_iter):
        ignis_mitigator_list.append(IgnisFilter(num_qubits, cal_matrices_list_list[num_qubits - 1][i]))
        if i % 10 == 0:
            print("iter", i, "finished")
    ignis_mitigator_list_list.append(ignis_mitigator_list)
    t2 = time.perf_counter()
    print("length of ignis_mitigator_list: ", len(ignis_mitigator_list))
    print("size", num_qubits, "finished (t=", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 1 finished (t= 0.0029341270001168596 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 2 finished (t= 0.00028883400045742746 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 3 finished (t= 0.0006220719988050405 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 4 finished (t= 0.0005493409989867359 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 5 finished (t= 0.0005324880003172439 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 6 finished (t= 0.0008235860004788265 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 7 finished (t= 0.000711237000359688 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 8 finished (t= 0.0008501629999955185 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 9 finished (t= 0.0014438170001085382 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 10 finished (t= 0.0011479709992272547 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 11 finished (t= 0.001400377999743796 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 12 finished (t= 0.0012277360001462512 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 13 finished (t= 0.0012609830009751022 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 14 finished (t= 0.0014850219995423686 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 15 finished (t= 0.0015854850007599453 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 16 finished (t= 0.001604486000360339 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 17 finished (t= 0.0019973279995610937 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 18 finished (t= 0.0018381010013399646 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 19 finished (t= 0.0017054950003512204 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 20 finished (t= 0.0018754369993985165 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 21 finished (t= 0.00207956899976125 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 22 finished (t= 0.0019925520009564934 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 23 finished (t= 0.002317938999112812 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 24 finished (t= 0.0023359930000879103 s)
#
# iter 0 finished
# length of ignis_mitigator_list:  10
# size 25 finished (t= 0.0028347080005914904 s)

# %%
def get_info(mitigator):
    return {"exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
ignis_info_list_list = []
ignis_hist_list_list = []
for i in range(min_size - 1, max_size):
    t1 = time.perf_counter()
    ignis_info_list = []
    ignis_hist_list = []
    for j in range(0, max_iter):
        ignis_hist_list.append( ignis_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
        ignis_info_list.append( get_info(ignis_mitigator_list_list[i][j]) )
        print("iter", j, "finished")
    ignis_hist_list_list.append( ignis_hist_list )
    ignis_info_list_list.append( ignis_info_list )
    t2 = time.perf_counter()
    print("size", i + 1, "finished (t=", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 1 finished (t= 0.0009140000001934823 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 2 finished (t= 0.0008433970015175873 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 3 finished (t= 0.0009392419997311663 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 4 finished (t= 0.0012168520006525796 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 5 finished (t= 0.0007128090001060627 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 6 finished (t= 0.0009132220002356917 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 7 finished (t= 0.0012144430002081208 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 8 finished (t= 0.002080620999549865 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 9 finished (t= 0.0026408419998915633 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 10 finished (t= 0.004368087000329979 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 11 finished (t= 0.008218105998821557 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 12 finished (t= 0.01566244500099856 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 13 finished (t= 0.027463296999485465 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 14 finished (t= 0.06149087399899145 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 15 finished (t= 0.15214567799921497 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 16 finished (t= 0.2603834990004543 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 17 finished (t= 0.5608114890001161 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 18 finished (t= 1.1935168629988766 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 19 finished (t= 2.7882294850005565 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 20 finished (t= 6.018223011000373 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 21 finished (t= 13.023055491001287 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 22 finished (t= 27.208923539999887 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 23 finished (t= 59.835087145000216 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 24 finished (t= 132.79101507300038 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 25 finished (t= 349.5262972080018 s)

# %%
with open("pkls/ignis_info_list_list.pkl", "wb") as f:
    pickle.dump(ignis_info_list_list, f)
with open("pkls/ignis_hist_list_list.pkl", "wb") as f:
    pickle.dump(ignis_hist_list_list, f)
