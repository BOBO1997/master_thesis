# %%
import sys
sys.path.append('../../../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from libs_qrem import DeltaFilter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_14890/3366053314.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 30

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/meas_fitter_list_list.pkl", "rb") as f:
    meas_fitter_list_list = pickle.load(f)

# %%
delta_mitigator_list_list = []
for num_qubits in range(min_size, max_size + 1):
    delta_mitigator_list = []
    for i in range(0, max_iter):
        delta_mitigator_list.append(DeltaFilter(num_qubits, meas_fitter_list_list[num_qubits - 1][i].cal_matrices))
        if i % 10 == 0:
            print("iter", i, "finished")
    delta_mitigator_list_list.append(delta_mitigator_list)
    print("length of delta_mitigator_list: ", len(delta_mitigator_list))
    print("size", num_qubits, "finished")
    print()
# Out:
# iter 0 finished
# length of delta_mitigator_list:  10
# size 1 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 2 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 3 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 4 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 5 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 6 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 7 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 8 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 9 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 10 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 11 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 12 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 13 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 14 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 15 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 16 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 17 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 18 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 19 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 20 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 21 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 22 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 23 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 24 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 25 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 26 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 27 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 28 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 29 finished
#
# iter 0 finished
# length of delta_mitigator_list:  10
# size 30 finished

# %%
def get_info(mitigator):
    return {"exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
delta_info_list_list = []
delta_hist_list_list = []
for i in range(min_size - 1, max_size):
    delta_info_list = []
    delta_hist_list = []
    for j in range(0, max_iter):
        delta_hist_list.append( delta_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
        delta_info_list.append( get_info(delta_mitigator_list_list[i][j]) )
        print("iter", j, "finished")
    delta_hist_list_list.append( delta_hist_list )
    delta_info_list_list.append( delta_info_list )
    print("size", i + 1, "finished")
    print()
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 1 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 2 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 3 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 4 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 5 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 6 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 7 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 8 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 9 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 10 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 11 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 12 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 13 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 14 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 15 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 16 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 17 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 18 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 19 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 20 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 21 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 22 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 23 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 24 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 25 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 26 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 27 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 28 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 29 finished
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 30 finished

# %%
with open("pkls/delta_info_list_list.pkl", "wb") as f:
    pickle.dump(delta_info_list_list, f)
with open("pkls/delta_hist_list_list.pkl", "wb") as f:
    pickle.dump(delta_hist_list_list, f)
