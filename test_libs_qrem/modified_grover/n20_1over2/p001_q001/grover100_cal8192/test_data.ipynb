# %%
import pickle
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/meas_fitters.pkl", "rb") as f:
    meas_fitters = pickle.load(f)
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_48077/403369812.py:5: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   meas_fitters = pickle.load(f)

# %%
with open("../../../n10_1over2/p001_q001/grover100_cal8192/pkls/raw_hist_list_list.pkl", "rb") as f:
    test_raw_hist_list_list = pickle.load(f)
with open("../../../n10_1over2/p001_q001/grover100_cal8192/pkls/meas_fitters.pkl", "rb") as f:
    test_meas_fitters = pickle.load(f)

# %%
test_raw_hist_list_list == raw_hist_list_list
# Out:
# False

# %%
test_raw_hist_list_list
# Out:
# [[{'00000000010': 1,
#    '10100000000': 1,
#    '00010000000': 1,
#    '10000000010': 1,
#    '00000100000': 1,
#    '00100000000': 2,
#    '00000000100': 1,
#    '11000000000': 4,
#    '01000000000': 2,
#    '10000000000': 21,
#    '00000000000': 64,
#    '10000100000': 1},
#   {'10010000000': 1,
#    '10000100000': 1,
#    '10100000000': 2,
#    '01000000000': 3,
#    '10000000100': 1,
#    '01010000000': 1,
#    '10001000000': 1,
#    '00000100000': 1,
#    '01000000100': 1,
#    '00000001001': 1,
#    '10000000000': 48,
#    '00000000000': 16,
#    '00000000100': 1,
#    '01000000010': 1,
#    '11000000000': 21},
#   {'10001000000': 1,
#    '00100000000': 2,
#    '11000000000': 6,
#    '10100000000': 4,
#    '00001000000': 1,
#    '00000010000': 1,
#    '01000000000': 5,
#    '10000010000': 1,
#    '00000000000': 37,
#    '10000000000': 38,
#    '00000100000': 2,
#    '00010000000': 2},
#   {'10000000010': 1,
#    '10010000000': 2,
#    '00100000000': 1,
#    '10000001000': 2,
# ...

# %%
raw_hist_list_list[0]
# Out:
# [{'000000000001000000000': 1,
#   '000000100000000010000': 1,
#   '000000000000000100000': 1,
#   '100001000000000000000': 2,
#   '000000000100000000000': 1,
#   '001000000000000000000': 2,
#   '000000000000000000010': 1,
#   '100000010000000000000': 1,
#   '000000000000000001000': 1,
#   '000000000000010000000': 1,
#   '101000000000000000000': 1,
#   '100010000000000000000': 1,
#   '000000000010000000000': 2,
#   '000000000000000000000': 56,
#   '000000000000000010000': 2,
#   '100000000000000010000': 1,
#   '000000100000000000000': 4,
#   '110000000000000000000': 4,
#   '100000000000000000000': 17},
#  {'110000010000000001000': 1,
#   '100000100000000000100': 1,
#   '000000000000001000000': 1,
#   '100000000100000000000': 1,
#   '100000000001000000000': 1,
#   '100010000000000000000': 1,
#   '101000000000000000000': 2,
#   '001000000000000000000': 1,
#   '110000100000001000000': 1,
#   '011000000000000000000': 1,
#   '000000000000000000000': 16,
#   '000001000000000000000': 1,
# ...
