# %%
import sys
sys.path.append('../../../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np
import time

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
import mthree
from qiskit.test.mock import FakeManhattan
from libs_qrem import sgs_algorithm_py
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_15495/482182139.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 65

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/cal_matrices_list_list.pkl", "rb") as f:
    cal_matrices_list_list = pickle.load(f)

# %%
mthree_lu_mitigator_list_list = []
for num_qubits in range(min_size, max_size + 1):
    t1 = time.perf_counter()
    mthree_lu_mitigator_list = []
    for i in range(0, max_iter):
        mit = mthree.M3Mitigation(FakeManhattan())
        mit.single_qubit_cals = cal_matrices_list_list[num_qubits - 1][i]
        mthree_lu_mitigator_list.append(mit)
        if i % 10 == 0:
            print("iter", i, "finished")
    mthree_lu_mitigator_list_list.append(mthree_lu_mitigator_list)
    t2 = time.perf_counter()
    print("length of mthree_lu_mitigator_list: ", len(mthree_lu_mitigator_list))
    print("size", num_qubits, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 1 finished (t = 0.10100724000000127 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 2 finished (t = 0.06521783899999889 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 3 finished (t = 0.11688318600000258 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 4 finished (t = 0.04802885100000509 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 5 finished (t = 0.1270882159999971 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 6 finished (t = 0.05012868099999679 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 7 finished (t = 0.048591985000001614 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 8 finished (t = 0.1397406149999938 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 9 finished (t = 0.053358648999996205 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 10 finished (t = 0.16331950200000023 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 11 finished (t = 0.050449211000000105 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 12 finished (t = 0.04923267299999878 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 13 finished (t = 0.05067720699999967 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 14 finished (t = 0.22193470500000245 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 15 finished (t = 0.04952490599999493 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 16 finished (t = 0.05027321499999715 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 17 finished (t = 0.05089108299999623 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 18 finished (t = 0.23338055199999985 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 19 finished (t = 0.04919987700000661 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 20 finished (t = 0.05120003800000461 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 21 finished (t = 0.05352923500000628 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 22 finished (t = 0.05072793699999778 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 23 finished (t = 0.28964612000000045 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 24 finished (t = 0.05042165299999368 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 25 finished (t = 0.049531758999997066 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 26 finished (t = 0.052223273999999265 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 27 finished (t = 0.05168238099999911 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 28 finished (t = 0.0511829280000029 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 29 finished (t = 0.395018149000002 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 30 finished (t = 0.057306381000003626 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 31 finished (t = 0.050051052999997125 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 32 finished (t = 0.04878985300000238 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 33 finished (t = 0.04804926100000273 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 34 finished (t = 0.04997198000000225 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 35 finished (t = 0.047574636000000226 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 36 finished (t = 0.04802064400000461 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 37 finished (t = 0.3957888810000014 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 38 finished (t = 0.04690077899999778 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 39 finished (t = 0.048970618999995 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 40 finished (t = 0.05094594199999847 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 41 finished (t = 0.05250342299999744 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 42 finished (t = 0.05257202099999603 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 43 finished (t = 0.053192778999999746 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 44 finished (t = 0.05123434400000093 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 45 finished (t = 0.05085584799999765 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 46 finished (t = 0.05021847999999807 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 47 finished (t = 0.47715900300000413 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 48 finished (t = 0.05597601500000593 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 49 finished (t = 0.048279536000002565 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 50 finished (t = 0.04785090200000042 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 51 finished (t = 0.04560857099999538 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 52 finished (t = 0.04751882499999738 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 53 finished (t = 0.0500792460000028 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 54 finished (t = 0.049594839000000945 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 55 finished (t = 0.050664595000000645 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 56 finished (t = 0.050928529000003664 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 57 finished (t = 0.04569208299999872 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 58 finished (t = 0.0483761549999997 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 59 finished (t = 0.6122320750000014 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 60 finished (t = 0.05072964099999666 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 61 finished (t = 0.04966398900000257 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 62 finished (t = 0.048963937000003455 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 63 finished (t = 0.04943966399999766 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 64 finished (t = 0.05031500300000147 s)
#
# iter 0 finished
# length of mthree_lu_mitigator_list:  10
# size 65 finished (t = 0.05022930699999506 s)

# %%
mthree_lu_info_list_list = []
mthree_lu_hist_list_list = []
for i in range(min_size - 1, max_size):
    t1 = time.perf_counter()
    mthree_lu_info_list = []
    mthree_lu_hist_list = []
    for j in range(0, max_iter):
        meas_layout = [k for k in range(i + 1)]
        mit_hist, info = mthree_lu_mitigator_list_list[i][j].apply_correction(raw_hist_list_list[i][j],
                                                                      meas_layout, 
                                                                      distance=None,
                                                                      method='direct',
                                                                      max_iter=25, 
                                                                      tol=1e-5,
                                                                      return_mitigation_overhead=True,
                                                                      details=True)
        mthree_lu_hist_list.append( sgs_algorithm_py(mit_hist) )
        mthree_lu_info_list.append( info )
        print("iter", j, "finished")
    mthree_lu_hist_list_list.append( mthree_lu_hist_list )
    mthree_lu_info_list_list.append( mthree_lu_info_list )
    t2 = time.perf_counter()
    print("size", i + 1, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 1 finished (t = 0.011529414999998266 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 2 finished (t = 0.005789507000002914 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 3 finished (t = 0.02372404100000125 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 4 finished (t = 0.008842102999999213 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 5 finished (t = 0.009075733000003083 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 6 finished (t = 0.009081107000000088 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 7 finished (t = 0.010912603999997827 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 8 finished (t = 0.013265760999999543 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 9 finished (t = 0.015557291999996892 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 10 finished (t = 0.015805868000001055 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 11 finished (t = 0.01606694000000175 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 12 finished (t = 0.018721681999998907 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 13 finished (t = 0.019778625999997246 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 14 finished (t = 0.02166394400000371 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 15 finished (t = 0.043563241000001085 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 16 finished (t = 0.02165600800000078 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 17 finished (t = 0.02159338400000621 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 18 finished (t = 0.022187241000004576 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 19 finished (t = 0.024619831999999064 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 20 finished (t = 0.02397072699999825 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 21 finished (t = 0.025465197000002604 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 22 finished (t = 0.026489864000005525 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 23 finished (t = 0.03367231899999723 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 24 finished (t = 0.035443527000005304 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 25 finished (t = 0.03875558699999715 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 26 finished (t = 0.04118091200000151 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 27 finished (t = 0.04728393299999567 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 28 finished (t = 0.054212420000006034 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 29 finished (t = 0.057852909000004615 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 30 finished (t = 0.09676773800000404 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 31 finished (t = 0.07241609300000107 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 32 finished (t = 0.0772363030000065 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 33 finished (t = 0.09404490400000043 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 34 finished (t = 0.09794122400000305 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 35 finished (t = 0.1010579490000012 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 36 finished (t = 0.11400712199999674 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 37 finished (t = 0.12769864999999925 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 38 finished (t = 0.14561952200000405 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 39 finished (t = 0.15437045999999555 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 40 finished (t = 0.17267466599999892 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 41 finished (t = 0.1818758230000057 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 42 finished (t = 0.20869451699999786 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 43 finished (t = 0.2294990489999975 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 44 finished (t = 0.2560376709999943 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 45 finished (t = 0.2807023669999964 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 46 finished (t = 0.3124623160000013 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 47 finished (t = 0.3143379410000051 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 48 finished (t = 0.3396533510000026 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 49 finished (t = 0.3664939479999987 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 50 finished (t = 0.4115519559999967 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 51 finished (t = 0.4684424179999951 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 52 finished (t = 0.47760367499999745 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 53 finished (t = 0.5247370170000067 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 54 finished (t = 0.5688468049999926 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 55 finished (t = 0.642672771000008 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 56 finished (t = 0.6656222210000067 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 57 finished (t = 0.7768518129999933 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 58 finished (t = 0.8245057980000041 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 59 finished (t = 0.8676656589999965 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 60 finished (t = 0.9291869439999942 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 61 finished (t = 1.0374546580000015 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 62 finished (t = 1.0640905709999942 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 63 finished (t = 1.2120036820000024 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 64 finished (t = 1.2607671450000026 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 65 finished (t = 1.4051035800000022 s)

# %%
def rescale_hist(hist, shots):
    new_hist = dict()
    for k, v in hist.items():
        new_hist[k] = v * shots
    return new_hist

# %%
for i in range(min_size - 1, max_size):
    for j in range(0, max_iter):
        mthree_lu_hist_list_list[i][j] = rescale_hist(mthree_lu_hist_list_list[i][j], 1 << 13)

# %%
with open("pkls/mthree_lu_info_list_list.pkl", "wb") as f:
    pickle.dump(mthree_lu_info_list_list, f)
with open("pkls/mthree_lu_hist_list_list.pkl", "wb") as f:
    pickle.dump(mthree_lu_hist_list_list, f)
