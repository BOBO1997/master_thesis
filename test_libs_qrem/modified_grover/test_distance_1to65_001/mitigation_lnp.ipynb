# %%
import sys
sys.path.append('../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from libs_qrem import LeastNormFilter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_15479/962561968.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 65

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/cal_matrices_list_list.pkl", "rb") as f:
    cal_matrices_list_list = pickle.load(f)

# %%
lnp_mitigator_list_list = []
for num_qubits in range(min_size, max_size + 1):
    t1 = time.perf_counter()
    lnp_mitigator_list = []
    for i in range(0, max_iter):
        lnp_mitigator_list.append(LeastNormFilter(num_qubits, cal_matrices_list_list[num_qubits - 1][i]))
        if i % 10 == 0:
            print("iter", i, "finished")
    lnp_mitigator_list_list.append(lnp_mitigator_list)
    t2 = time.perf_counter()
    print("length of lnp_mitigator_list: ", len(lnp_mitigator_list))
    print("size", num_qubits, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 1 finished (t = 0.0005741539999999379 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 2 finished (t = 0.00042357400000003764 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 3 finished (t = 0.00038593699999989184 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 4 finished (t = 0.0006854830000000423 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 5 finished (t = 0.0007480840000000377 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 6 finished (t = 0.0007154369999999854 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 7 finished (t = 0.0009634579999999726 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 8 finished (t = 0.0008615569999999018 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 9 finished (t = 0.0008910380000000107 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 10 finished (t = 0.0009484760000000314 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 11 finished (t = 0.0011234610000001588 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 12 finished (t = 0.0011196479999999731 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 13 finished (t = 0.0012652199999998448 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 14 finished (t = 0.0013971040000000379 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 15 finished (t = 0.0017781230000000203 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 16 finished (t = 0.0017704889999998752 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 17 finished (t = 0.0016392600000001423 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 18 finished (t = 0.0016497689999999121 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 19 finished (t = 0.0017387810000000226 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 20 finished (t = 0.001793038000000191 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 21 finished (t = 0.002168751999999996 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 22 finished (t = 0.0021681140000000543 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 23 finished (t = 0.002256441000000109 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 24 finished (t = 0.002476034999999932 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 25 finished (t = 0.002292508999999887 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 26 finished (t = 0.002491353999999779 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 27 finished (t = 0.0026655199999998658 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 28 finished (t = 0.002521747999999935 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 29 finished (t = 0.0028022019999998093 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 30 finished (t = 0.0025561849999999886 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 31 finished (t = 0.0026948559999997457 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 32 finished (t = 0.0028399279999997695 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 33 finished (t = 0.002906695999999709 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 34 finished (t = 0.002934601999999842 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 35 finished (t = 0.002914162999999803 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 36 finished (t = 0.0029925609999996716 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 37 finished (t = 0.0030840190000001044 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 38 finished (t = 0.0032376740000001902 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 39 finished (t = 0.0035541320000000987 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 40 finished (t = 0.0033585739999999475 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 41 finished (t = 0.003452946999999984 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 42 finished (t = 0.0035886299999998705 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 43 finished (t = 0.003643183999999966 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 44 finished (t = 0.004539536999999871 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 45 finished (t = 0.004478826000000158 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 46 finished (t = 0.003831130000000016 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 47 finished (t = 0.004505586000000061 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 48 finished (t = 0.0040470699999999304 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 49 finished (t = 0.0041298959999998 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 50 finished (t = 0.004145620999999711 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 51 finished (t = 0.004213475000000244 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 52 finished (t = 0.004358502000000097 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 53 finished (t = 0.004422621999999876 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 54 finished (t = 0.00627628999999974 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 55 finished (t = 0.005434001999999882 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 56 finished (t = 0.004837905000000031 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 57 finished (t = 0.0048168539999999815 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 58 finished (t = 0.004853055999999967 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 59 finished (t = 0.005151812000000255 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 60 finished (t = 0.004985773999999665 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 61 finished (t = 0.005182474000000159 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 62 finished (t = 0.0057264679999997625 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 63 finished (t = 0.006170657999999829 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 64 finished (t = 0.005616355999999989 s)
#
# iter 0 finished
# length of lnp_mitigator_list:  10
# size 65 finished (t = 0.006130165000000076 s)

# %%
def get_info(mitigator):
    return {"exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
lnp_info_list_list = []
lnp_hist_list_list = []
for i in range(min_size - 1, max_size):
    t1 = time.perf_counter()
    lnp_info_list = []
    lnp_hist_list = []
    for j in range(0, max_iter):
        lnp_hist_list.append( lnp_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
        lnp_info_list.append( get_info(lnp_mitigator_list_list[i][j]) )
        print("iter", j, "finished")
    lnp_hist_list_list.append( lnp_hist_list )
    lnp_info_list_list.append( lnp_info_list )
    t2 = time.perf_counter()
    print("size", i + 1, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 1 finished (t = 0.0011988419999990896 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 2 finished (t = 0.0016432509999990685 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 3 finished (t = 0.001213298999999779 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 4 finished (t = 0.0009098739999995331 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 5 finished (t = 0.0009365139999992778 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 6 finished (t = 0.0011487300000005973 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 7 finished (t = 0.0012724669999997218 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 8 finished (t = 0.0014618839999993583 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 9 finished (t = 0.0013734310000010908 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 10 finished (t = 0.0016304050000002235 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 11 finished (t = 0.002483866999998696 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 12 finished (t = 0.0037186250000011967 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 13 finished (t = 0.0032555729999987904 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 14 finished (t = 0.003926379999999341 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 15 finished (t = 0.004171448000001021 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 16 finished (t = 0.00532430699999864 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 17 finished (t = 0.007546153999999916 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 18 finished (t = 0.007127558000000533 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 19 finished (t = 0.008561715000000802 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 20 finished (t = 0.009095609000000948 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 21 finished (t = 0.010282847000000928 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 22 finished (t = 0.05504552400000051 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 23 finished (t = 0.018718651000000364 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 24 finished (t = 0.021426855999999717 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 25 finished (t = 0.026405647000000698 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 26 finished (t = 0.027928207000000427 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 27 finished (t = 0.04539989799999944 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 28 finished (t = 0.04152962999999943 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 29 finished (t = 0.0441212740000001 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 30 finished (t = 0.05456998400000046 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 31 finished (t = 0.058411215999999655 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 32 finished (t = 0.06843602500000046 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 33 finished (t = 0.0701989619999992 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 34 finished (t = 0.08906459700000013 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 35 finished (t = 0.09403933000000109 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 36 finished (t = 0.1416756380000006 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 37 finished (t = 0.11798703200000027 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 38 finished (t = 0.13911494100000077 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 39 finished (t = 0.1477895070000006 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 40 finished (t = 0.1666997230000007 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 41 finished (t = 0.17551244000000032 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 42 finished (t = 0.19138892399999996 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 43 finished (t = 0.23156165299999998 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 44 finished (t = 0.25724731500000075 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 45 finished (t = 0.26574090000000083 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 46 finished (t = 0.2884163649999998 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 47 finished (t = 0.3204445809999985 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 48 finished (t = 0.3353189839999988 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 49 finished (t = 0.34395919500000005 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 50 finished (t = 0.38847260600000055 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 51 finished (t = 0.4194808400000003 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 52 finished (t = 0.4513363140000006 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 53 finished (t = 0.5133984110000007 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 54 finished (t = 0.5571209910000015 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 55 finished (t = 0.5843581240000013 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 56 finished (t = 0.6390994140000004 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 57 finished (t = 0.6630350510000014 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 58 finished (t = 0.7691782139999965 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 59 finished (t = 0.8036763760000021 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 60 finished (t = 0.8676738069999992 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 61 finished (t = 0.932843290000001 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 62 finished (t = 0.9867378270000025 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 63 finished (t = 1.002660009000003 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 64 finished (t = 1.0633235019999994 s)
#
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# size 65 finished (t = 1.258912371000001 s)

# %%
with open("pkls/lnp_info_list_list.pkl", "wb") as f:
    pickle.dump(lnp_info_list_list, f)
with open("pkls/lnp_hist_list_list.pkl", "wb") as f:
    pickle.dump(lnp_hist_list_list, f)
