# %%
import sys
sys.path.append('../../../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from libs_qrem import MooneyEtalFilter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_15506/3754816221.py:1: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import TensoredMeasFitter

# %%
max_iter = 10
min_size = 1
max_size = 65

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    raw_hist_list_list = pickle.load(f)
with open("pkls/cal_matrices_list_list.pkl", "rb") as f:
    cal_matrices_list_list = pickle.load(f)

# %%
mooney001_mitigator_list_list = []
for num_qubits in range(min_size, max_size + 1):
    t1 = time.perf_counter()
    mooney001_mitigator_list = []
    for i in range(0, max_iter):
        mooney001_mitigator_list.append(MooneyEtalFilter(num_qubits, cal_matrices_list_list[num_qubits - 1][i]))
        if i % 10 == 0:
            print("iter", i, "finished")
    mooney001_mitigator_list_list.append(mooney001_mitigator_list)
    t2 = time.perf_counter()
    print("length of mooney001_mitigator_list: ", len(mooney001_mitigator_list))
    print("size", num_qubits, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 1 finished (t = 0.002557317999997366 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 2 finished (t = 0.0005491830000003972 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 3 finished (t = 0.0004491209999990531 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 4 finished (t = 0.0004392170000002693 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 5 finished (t = 0.0005080419999998753 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 6 finished (t = 0.0006275840000000699 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 7 finished (t = 0.0009457769999983157 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 8 finished (t = 0.0007490819999986797 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 9 finished (t = 0.0009872629999989613 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 10 finished (t = 0.0009669549999991034 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 11 finished (t = 0.00109052000000176 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 12 finished (t = 0.0011979669999995224 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 13 finished (t = 0.0011949930000021425 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 14 finished (t = 0.0012838200000011568 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 15 finished (t = 0.0014761790000008546 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 16 finished (t = 0.0017030059999996183 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 17 finished (t = 0.0018648470000002249 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 18 finished (t = 0.0018629169999968553 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 19 finished (t = 0.0019428750000010098 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 20 finished (t = 0.0019237029999992217 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 21 finished (t = 0.0018480109999998717 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 22 finished (t = 0.00193916999999999 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 23 finished (t = 0.002176653999999445 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 24 finished (t = 0.002396956999998423 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 25 finished (t = 0.0022451480000000856 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 26 finished (t = 0.002426839000001735 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 27 finished (t = 0.002941654999997212 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 28 finished (t = 0.0027967199999991976 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 29 finished (t = 0.0026138250000009577 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 30 finished (t = 0.002624292000000139 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 31 finished (t = 0.0026948910000008652 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 32 finished (t = 0.00270256900000021 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 33 finished (t = 0.0033545619999983955 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 34 finished (t = 0.003031513999999902 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 35 finished (t = 0.003083110000002165 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 36 finished (t = 0.003388469000000782 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 37 finished (t = 0.0032898320000001036 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 38 finished (t = 0.0032453080000003354 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 39 finished (t = 0.003551290000000762 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 40 finished (t = 0.0035426299999983257 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 41 finished (t = 0.0034299209999986147 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 42 finished (t = 0.0035110689999982014 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 43 finished (t = 0.003629689000000269 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 44 finished (t = 0.0037511289999976327 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 45 finished (t = 0.0037831300000021884 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 46 finished (t = 0.003826696000000851 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 47 finished (t = 0.0038534259999991605 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 48 finished (t = 0.004040951999996878 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 49 finished (t = 0.009506191999999913 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 50 finished (t = 0.013269034000000346 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 51 finished (t = 0.004862568000000067 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 52 finished (t = 0.004982645000001895 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 53 finished (t = 0.004802431000001661 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 54 finished (t = 0.0049631430000012244 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 55 finished (t = 0.005229277000001531 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 56 finished (t = 0.0050561490000013976 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 57 finished (t = 0.0049822329999997805 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 58 finished (t = 0.005234777999998386 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 59 finished (t = 0.004925940999999767 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 60 finished (t = 0.005689115000002687 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 61 finished (t = 0.005632656999999597 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 62 finished (t = 0.005193379000001386 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 63 finished (t = 0.0059213119999981245 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 64 finished (t = 0.0056105990000006045 s)
#
# iter 0 finished
# length of mooney001_mitigator_list:  10
# size 65 finished (t = 0.006481760999999864 s)

# %%
def get_info(mitigator):
    return {# "exact_one_norm_of_reduced_inv_A": mitigator.exact_one_norm_of_reduced_inv_A(),
            "mitigated_hist": mitigator.mitigated_hist(),
            "times": mitigator.times(),
            "mitigation_stddev": mitigator.mitigation_stddev(norm_type = "exact"),
            }

# %%
mooney001_info_list_list = []
mooney001_hist_list_list = []
for i in range(min_size - 1, max_size):
    t1 = time.perf_counter()
    mooney001_info_list = []
    mooney001_hist_list = []
    for j in range(0, max_iter):
        mooney001_hist_list.append( mooney001_mitigator_list_list[i][j].apply(raw_hist_list_list[i][j]) )
        mooney001_info_list.append( get_info(mooney001_mitigator_list_list[i][j]) )
        print("iter", j, "finished")
    mooney001_hist_list_list.append( mooney001_hist_list )
    mooney001_info_list_list.append( mooney001_info_list )
    t2 = time.perf_counter()
    print("size", num_qubits, "finished (t =", t2 - t1, "s)")
    print()
# Out:
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0014834260000000654 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0016280080000043995 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.001162974999999733 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0009510940000012624 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0008440200000023879 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0017005199999999832 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.001569998999997324 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0013397700000012946 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0013146120000016026 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.001397690000004559 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0014216769999961798 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.001519096000002662 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.013138963000002946 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.005538493000003086 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.002937060999997243 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0028318519999999126 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.041192308000006506 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.003174228999995421 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.00367062599999457 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.003505693999997561 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.004306909000000303 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.004270197000003861 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.005631524000001775 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.00706968299999744 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.023521893999998156 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.008112983000003737 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.007605085000001566 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.08408728500000251 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.010041785999995056 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.010134065000002579 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.010904014000004736 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.010652645999996935 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.01015439700000087 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.009905822000000342 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.011420860000001198 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.011277875000004656 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.011626542000001905 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.014077595999999915 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.07676109199999814 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.014710008999998081 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.014402984000000174 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.016712769999998045 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.016665424999999345 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.01878182400000128 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.017895685999995692 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.01913645099999428 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.01868560700000188 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.019249801999997374 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.019696177000000148 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0646811679999999 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.023482395999998573 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.02206992600000035 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.022840103999996586 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.025091353000000538 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.02551885399999776 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.025784353999995346 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.026238064999994037 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.026550625999995248 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.026478507999996737 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.031242946999995524 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.0652589230000018 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.03183202000000307 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.03200843100000128 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.034741672000002666 s)
#
# Cannot compute the standard deviation of mitigation.
# iter 0 finished
# Cannot compute the standard deviation of mitigation.
# iter 1 finished
# Cannot compute the standard deviation of mitigation.
# iter 2 finished
# Cannot compute the standard deviation of mitigation.
# iter 3 finished
# Cannot compute the standard deviation of mitigation.
# iter 4 finished
# Cannot compute the standard deviation of mitigation.
# iter 5 finished
# Cannot compute the standard deviation of mitigation.
# iter 6 finished
# Cannot compute the standard deviation of mitigation.
# iter 7 finished
# Cannot compute the standard deviation of mitigation.
# iter 8 finished
# Cannot compute the standard deviation of mitigation.
# iter 9 finished
# size 65 finished (t = 0.03283039600000137 s)

# %%
with open("pkls/mooney001_info_list_list.pkl", "wb") as f:
    pickle.dump(mooney001_info_list_list, f)
with open("pkls/mooney001_hist_list_list.pkl", "wb") as f:
    pickle.dump(mooney001_hist_list_list, f)
