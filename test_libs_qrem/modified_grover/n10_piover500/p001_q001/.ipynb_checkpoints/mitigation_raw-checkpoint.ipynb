# %%
import sys
sys.path.append('../../')
from pprint import pprint
import time
import pickle
import importlib
import numpy as np

# %%
from qiskit.ignis.mitigation.measurement import TensoredMeasFitter
from lib_grover import make_hit_list

# %%
nbit = 10 # change this value to get discretized result closer to analytical results # 3
#setting the number of shots and Grover operators.
max_iter = 10
number_grover_list = [1, 2, 4, 8, 16, 32, 64]  # list of number of Grover operators
shots = 8192
shots_list = [shots] * len(number_grover_list) # list of number of shots
if len(shots_list) != len(number_grover_list):
    raise Exception('The length of shots_list should be equal to the length eof number_grover_list.')

# %%
with open("pkls/raw_hist_list_list.pkl", "rb") as f:
    hist_list_list = pickle.load(f)
with open("pkls/meas_fitters.pkl", "rb") as f:
    meas_fitters = pickle.load(f)

# %%
from libs_qrem import LeastNormFilter

# %%
lnp_mitigator_list = []
for i in range(0, max_iter):
    lnp_mitigator_list.append(LeastNormFilter(nbit + 1, meas_fitters[i].cal_matrices))
    if i % 10 == 0:
        print("size", i, "finished")
print("length of lnp_mitigator_list: ", len(lnp_mitigator_list))
# Out:
# size 0 finished
# length of lnp_mitigator_list:  10

# %%
raw_hit_list_list = []
for i in range(max_iter):
    raw_hit_list_list.append( make_hit_list(hist_list_list[i]) )
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished

# %%
with open("pkls/raw_hit_list_list.pkl", "wb") as f:
    pickle.dump(raw_hit_list_list, f)

# %%
ignis_hit_list_list, ignis_time_list_list = [], []
for i, hist_list in enumerate(hist_list_list):
    ignis_hist_list, ignis_time_list = [], []
    for hist in hist_list:
        t1 = time.perf_counter()
        ignis_hist_list.append( ignis_mitigator_list[i].apply(hist) )
        t2 = time.perf_counter()
        ignis_time_list.append( t2 - t1 )
        print("hist", t2 - t1, "s")
    ignis_hit_list_list.append( make_hit_list(ignis_hist_list) )
    ignis_time_list_list.append( ignis_time_list )
    print("iter", i, "finished\n")

# %%
with open("pkls/ignis_hit_list_list.pkl", "wb") as f:
    pickle.dump(ignis_hit_list_list, f)

# %%
lnp_hit_list_list, lnp_time_list_list = [], []
for i, hist_list in enumerate(hist_list_list):
    lnp_hist_list, lnp_time_list = [], []
    for hist in hist_list:
        lnp_hist_list.append( lnp_mitigator_list[i].apply(hist) )
        lnp_time_list.append( lnp_mitigator_list[i].times() )
    lnp_hit_list_list.append( make_hit_list(lnp_hist_list) )
    lnp_time_list_list.append( lnp_time_list )
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("pkls/lnp_hit_list_list.pkl", "wb") as f:
    pickle.dump(lnp_hit_list_list, f)
with open("pkls/lnp_time_list_list.pkl", "wb") as f:
    pickle.dump(lnp_time_list_list, f)

# %%
s_lm0_hit_list_list, s_lm0_time_list_list = [], []
for i, hist_list in enumerate(hist_list_list):
    s_lm0_hist_list, s_lm0_time_list = [], []
    for hist in hist_list:
        s_lm0_hist_list.append( s_lm0_mitigator_list[i].apply(hist) )
        s_lm0_time_list.append( s_lm0_mitigator_list[i].times() )
    s_lm0_hit_list_list.append( make_hit_list(s_lm0_hist_list) )
    s_lm0_time_list_list.append( s_lm0_time_list )
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("pkls/s_lm0_hit_list_list.pkl", "wb") as f:
    pickle.dump(s_lm0_hit_list_list, f)
with open("pkls/s_lm0_time_list_list.pkl", "wb") as f:
    pickle.dump(s_lm0_time_list_list, f)

# %%
mooney01_hit_list_list, mooney01_time_list_list = [], []
for i, hist_list in enumerate(hist_list_list):
    mooney01_hist_list, mooney01_time_list = [], []
    for hist in hist_list:
        mooney01_hist_list.append( mooney_mitigator_list[i].apply(hist, threshold = 0.1) )
        mooney01_time_list.append( mooney_mitigator_list[i].times() )
    mooney01_hit_list_list.append( make_hit_list(mooney01_hist_list) )
    mooney01_time_list_list.append( mooney01_time_list )
    print("iter", i, "finished")
# Out:
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 0 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positer 1 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring thitere necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might ev 2 finished
# iteren ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv 3 finished
# e, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulaiter 4 finished
# tor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive vaiter 5 finished
# lues.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessiter al positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignor6 finished
# itering the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we mi 7 finished
# ght even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is piter 8 finished
# iter 9 ositive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# acfinished
# itercumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal posit 10 finished
# ive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the iter necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even11 finished
#  ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulatoiterr is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal 12 finished
# iter positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignorin 13 finished
# g the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we mighiter 14 finished
# iter 15 finished
# t even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positer 16 finished
# itive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accuiter 17 finished
# iter 18 finished
# itermulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positiv 19 finished
# itere values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the ne 20 finished
# itercessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even i 21 finished
# gnoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, witere might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator  22 finished
# iteris positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values 23 finished
# iter.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal p 24 finished
# ositive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring iterthe necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is posit ive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumu25 finished
# iterlator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive  26 finished
# values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even igniter 27 finished
# oring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we itermight even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is 28 finished
#  positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 29 accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal posfinished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring thitere necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might ev 30 finisheden ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv
# e, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulaitertor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive va 31 finished
# iterlues.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necess 32al positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# ...
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might eviter 96 finished
# iteren ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv 97 finished
# e, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulaitertor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive va 98 finished
# lues.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessiteral positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignor 99 finished
# ing the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.

# %%
with open("pkls/mooney01_hit_list_list.pkl", "wb") as f:
    pickle.dump(mooney01_hit_list_list, f)
with open("pkls/mooney01_time_list_list.pkl", "wb") as f:
    pickle.dump(mooney01_time_list_list, f)

# %%
mooney001_hit_list_list, mooney001_time_list_list = [], []
for i, hist_list in enumerate(hist_list_list):
    mooney001_hist_list, mooney001_time_list = [], []
    for hist in hist_list:
        mooney001_hist_list.append( mooney_mitigator_list[i].apply(hist, threshold = 0.01) )
        mooney001_time_list.append( mooney_mitigator_list[i].times() )
    mooney001_hit_list_list.append( make_hit_list(mooney001_hist_list) )
    mooney001_time_list_list.append( mooney001_time_list )
    print("iter", i, "finished")
# Out:
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 0 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positeritive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring th 1 finished
# e necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 2 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positer 3 finished
# iteritive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring th 4 finished
# itere necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might ev 5 finished
# iter 6 finished
# iteren ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv 7 finished
# itere, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumula 8 finished
# tor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive vaiterlues.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necess al positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignor9 finished
# ing the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we miiterght even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is p 10 finished
# iter 11 finished
# ositive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# aciter 12 finished
# itercumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal posit 13 finished
# iter 14 ive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the finished
# necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive,iter 15 finished
# iter 16 finished
#  we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulatoiter 17 finished
# iter 18 finished
# r is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive valuiter 19 finished
# iteres.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal 20 finished
# iter 21 finished
# iter positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignorin 22 finished
# g the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we mighiter 23 finished
# itert even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is pos 24 finished
# itive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accuiter 25 finished
# mulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positivitere values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the ne 26 finished
# cessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even iiter 27 finished
# gnoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, witer e might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator 28 finished
# is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might iter even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is posit29ive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive  finishedvalues.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the nece
# ssal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even igniter 30 finished
# oring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we itermight even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is 31 finished
#  positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iteraccumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal pos 32 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring thitere necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might ev en ignoring the necessal positive values.
# 33 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iteraccumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
#  34 finished
# iteraccumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
#  35 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positer 36 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# ...
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv 90 finished
# itere, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumula 91 finished
# tor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iteraccumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal pos 92 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring thitere necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
#  93 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positer 94 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring thiter 95 finished
# e necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might eviteren ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positiv 96 finished
# e, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulaitertor is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
#  97 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 98 finished
# iteraccumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal pos 99 finished
# itive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.

# %%
with open("pkls/mooney001_hit_list_list.pkl", "wb") as f:
    pickle.dump(mooney001_hit_list_list, f)
with open("pkls/mooney001_time_list_list.pkl", "wb") as f:
    pickle.dump(mooney001_time_list_list, f)

# %%
nation_hit_list_list, nation_time_list_list = [], []
meas_layout = [j for j in range(nbit + 1)]
for i, hist_list in enumerate(hist_list_list):
    nation_hist_list, nation_time_list = [], []
    for hist in hist_list:
        mit_hist, info = nation_mitigator_list[i].apply_correction(hist,
                                                                   meas_layout, 
                                                                   distance=None,
                                                                   method='iterative',
                                                                   max_iter=25, 
                                                                   tol=1e-5,
                                                                   return_mitigation_overhead=True,
                                                                   details=True)
        nation_hist_list.append( mit_hist )
        nation_time_list.append( info )
    nation_hit_list_list.append( make_hit_list(nation_hist_list) )
    nation_time_list_list.append( nation_time_list )
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("pkls/nation_hit_list_list.pkl", "wb") as f:
    pickle.dump(nation_hit_list_list, f)
with open("pkls/nation_time_list_list.pkl", "wb") as f:
    pickle.dump(nation_time_list_list, f)
