# %% [markdown]
# ### Approximating the integral
#
# It is easy to see that as we use large $n$ (i.e., more qubits) and thus larger $b_{\mbox{max}}$, we can approximate the integral better as illustrated below.

# %%
import math

b_max = math.pi / 100  # upper limit of integral # 5
nbit = 10  # change this value to get discretized result closer to analytical results # 3

analyticResult = (b_max / 2.0 - math.sin(2 * b_max) / 4.0 ) / b_max  # the target integral can be analytically solved
print("Analytical Result:", analyticResult)

ndiv = 2**nbit  #number of discretization 
discretizedResult = 0.0
for i in range(ndiv):
    discretizedResult += math.sin(b_max / ndiv * (i + 0.5))**2
discretizedResult = discretizedResult / ndiv
print("Discretized Result:", discretizedResult)
# Out:
# Analytical Result: 0.00032892188007938847
# Discretized Result: 0.0003289218016943769

# %%
import sys
sys.path.append('../')

# %%
#Preparing qiskit environment
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute
from qiskit import IBMQ
from qiskit import Aer
from scipy import optimize
import sys, time
import mpmath as mp
import numpy as np
import matplotlib.pyplot as plt
import pickle
np.random.seed(42)
seed = 42

# %%
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise import QuantumError, ReadoutError
from qiskit.providers.aer.noise import depolarizing_error
import qiskit.ignis.mitigation as mit
from qiskit.ignis.mitigation.measurement import tensored_meas_cal, TensoredMeasFitter
from lib_grover import *

# %% [markdown]
# ## Testing the algorithm with simulators
#
# Let us run the algorithm with simulators

# %%
#setting the number of shots and Grover operators.
max_iter = 100
# number_grover_list = [0, 1, 2, 4, 8, 16, 32] # , 64, 128, 256]  # list of number of Grover operators
number_grover_list = [5 * i for i in range(20)]
shots_list = [100] * len(number_grover_list) # list of number of shots
if len(shots_list) != len(number_grover_list):
    raise Exception(
        'The length of shots_list should be equal to the length of number_grover_list.'
    )

backend = Aer.get_backend('qasm_simulator')

# %%
noise_model = NoiseModel()
for qi in range(nbit+1):
    if qi >= 0:
        read_err = ReadoutError([[0.990, 0.010],[0.010,0.990]])
        noise_model.add_readout_error(read_err, [qi])

# %% [markdown]
# Finally, we can run the algorithm as below:

# %%
qc_list = create_grover_circuit(number_grover_list, nbit,b_max)  # list of Grover circuits

# %%
t1 = time.time()
counts_lists = []
for i in range(max_iter): # set the seed as index i
    counts_list = run_grover(qc_list, number_grover_list, shots_list, backend, noise_model=noise_model, seed_transpiler=i, seed_simulator=i)  # list of number of grover operators
    counts_lists.append(counts_list)
    with open("p001_q001_piover100.pkl", "wb") as f:
        pickle.dump(counts_lists, f)
    print("iter", i, "finished")
t2 = time.time()
print(t2-t1)
# Out:
# 0 th round with 0 oracles
# 0.08847427368164062 s
# 1 th round with 5 oracles
# 0.5242743492126465 s
# 2 th round with 10 oracles
# 0.9794130325317383 s
# 3 th round with 15 oracles
# 1.363023042678833 s
# 4 th round with 20 oracles
# 1.8775241374969482 s
# 5 th round with 25 oracles
# 2.189688205718994 s
# 6 th round with 30 oracles
# 2.661684989929199 s
# 7 th round with 35 oracles
# 3.018967866897583 s
# 8 th round with 40 oracles
# 3.830798864364624 s
# 9 th round with 45 oracles
# 4.118872880935669 s
# 10 th round with 50 oracles
# 4.768141031265259 s
# 11 th round with 55 oracles
# 5.234081029891968 s
# 12 th round with 60 oracles
# 5.378868103027344 s
# 13 th round with 65 oracles
# 5.702710866928101 s
# 14 th round with 70 oracles
# 6.822056293487549 s
# 15 th round with 75 oracles
# 7.839592218399048 s
# 16 th round with 80 oracles
# 8.140820980072021 s
# 17 th round with 85 oracles
# 9.10304307937622 s
# 18 th round with 90 oracles
# 9.990681171417236 s
# 19 th round with 95 oracles
# 10.95215106010437 s
# iter 0 finished
# 0 th round with 0 oracles
# 0.007884025573730469 s
# 1 th round with 5 oracles
# 0.5198409557342529 s
# 2 th round with 10 oracles
# 1.0355010032653809 s
# 3 th round with 15 oracles
# 1.6349780559539795 s
# 4 th round with 20 oracles
# 1.9827840328216553 s
# 5 th round with 25 oracles
# 2.360244035720825 s
# 6 th round with 30 oracles
# 3.011826753616333 s
# 7 th round with 35 oracles
# 4.537001132965088 s
# 8 th round with 40 oracles
# 4.233221054077148 s
# 9 th round with 45 oracles
# 4.3485329151153564 s
# 10 th round with 50 oracles
# 4.8706278800964355 s
# 11 th round with 55 oracles
# 5.3138720989227295 s
# 12 th round with 60 oracles
# 6.034588813781738 s
# 13 th round with 65 oracles
# 8.687777996063232 s
# 14 th round with 70 oracles
# 13.439947128295898 s
# 15 th round with 75 oracles
# 15.399721145629883 s
# 16 th round with 80 oracles
# 16.041908979415894 s
# 17 th round with 85 oracles
# 15.991009950637817 s
# 18 th round with 90 oracles
# 25.280944108963013 s
# 19 th round with 95 oracles
# 21.92307186126709 s
# iter 1 finished
# 0 th round with 0 oracles
# 0.015706777572631836 s
# 1 th round with 5 oracles
# 0.914470911026001 s
# 2 th round with 10 oracles
# 1.9930059909820557 s
# 3 th round with 15 oracles
# 2.6985321044921875 s
# 4 th round with 20 oracles
# 3.4048099517822266 s
# 5 th round with 25 oracles
# 3.9235968589782715 s
# 6 th round with 30 oracles
# 5.305009841918945 s
# 7 th round with 35 oracles
# 7.096773147583008 s
# 8 th round with 40 oracles
# 8.071964979171753 s
# 9 th round with 45 oracles
# 6.8114402294158936 s
# 10 th round with 50 oracles
# 7.159389972686768 s
# 11 th round with 55 oracles
# 7.742586851119995 s
# 12 th round with 60 oracles
# 8.411881923675537 s
# 13 th round with 65 oracles
# 9.075630187988281 s
# 14 th round with 70 oracles
# 10.047591924667358 s
# 15 th round with 75 oracles
# 10.68471908569336 s
# 16 th round with 80 oracles
# 11.168087005615234 s
# 17 th round with 85 oracles
# 12.315924882888794 s
# 18 th round with 90 oracles
# 12.498073101043701 s
# 19 th round with 95 oracles
# 14.080045938491821 s
# iter 2 finished
# 0 th round with 0 oracles
# 0.014248371124267578 s
# 1 th round with 5 oracles
# 0.8026080131530762 s
# 2 th round with 10 oracles
# 1.57365083694458 s
# 3 th round with 15 oracles
# 2.2526228427886963 s
# 4 th round with 20 oracles
# 2.9517970085144043 s
# 5 th round with 25 oracles
# 3.872789144515991 s
# 6 th round with 30 oracles
# 4.284597158432007 s
# 7 th round with 35 oracles
# 5.091551065444946 s
# 8 th round with 40 oracles
# 5.727164268493652 s
# 9 th round with 45 oracles
# 6.731601238250732 s
# 10 th round with 50 oracles
# 7.486660003662109 s
# 11 th round with 55 oracles
# 7.920053958892822 s
# 12 th round with 60 oracles
# 8.543155193328857 s
# 13 th round with 65 oracles
# 9.773007869720459 s
# 14 th round with 70 oracles
# 10.250001907348633 s
# 15 th round with 75 oracles
# 11.196489095687866 s
# 16 th round with 80 oracles
# 11.90032696723938 s
# 17 th round with 85 oracles
# 11.768184900283813 s
# 18 th round with 90 oracles
# 13.326074838638306 s
# 19 th round with 95 oracles
# 13.309761047363281 s
# iter 3 finished
# 0 th round with 0 oracles
# 0.025726318359375 s
# 1 th round with 5 oracles
# 0.8047621250152588 s
# 2 th round with 10 oracles
# 1.6100988388061523 s
# 3 th round with 15 oracles
# 2.1467442512512207 s
# 4 th round with 20 oracles
# 2.830570936203003 s
# 5 th round with 25 oracles
# 3.4929981231689453 s
# 6 th round with 30 oracles
# 4.214598178863525 s
# 7 th round with 35 oracles
# 4.962691783905029 s
# 8 th round with 40 oracles
# 6.06310772895813 s
# 9 th round with 45 oracles
# 6.668734073638916 s
# 10 th round with 50 oracles
# 7.0589282512664795 s
# 11 th round with 55 oracles
# 8.015481948852539 s
# 12 th round with 60 oracles
# 8.530388832092285 s
# 13 th round with 65 oracles
# 9.445629835128784 s
# 14 th round with 70 oracles
# 10.299072027206421 s
# 15 th round with 75 oracles
# 10.719206809997559 s
# 16 th round with 80 oracles
# 11.168860912322998 s
# 17 th round with 85 oracles
# 12.569382190704346 s
# 18 th round with 90 oracles
# 12.633110046386719 s
# 19 th round with 95 oracles
# 13.955118894577026 s
# iter 4 finished
# 0 th round with 0 oracles
# 0.014059066772460938 s
# 1 th round with 5 oracles
# 0.764646053314209 s
# 2 th round with 10 oracles
# 1.4905080795288086 s
# 3 th round with 15 oracles
# 2.1126227378845215 s
# 4 th round with 20 oracles
# 2.8318047523498535 s
# 5 th round with 25 oracles
# 3.4721481800079346 s
# 6 th round with 30 oracles
# 2.795677900314331 s
# 5 th round with 25 oracles
# 3.6187469959259033 s
# 6 th round with 30 oracles
# 4.146812915802002 s
# 7 th round with 35 oracles
# 4.735567808151245 s
# 8 th round with 40 oracles
# 5.508041143417358 s
# 9 th round with 45 oracles
# 5.936557769775391 s
# 10 th round with 50 oracles
# 6.898021936416626 s
# 11 th round with 55 oracles
# 7.966156959533691 s
# 12 th round with 60 oracles
# 7.9272072315216064 s
# 13 th round with 65 oracles
# 9.328593015670776 s
# 14 th round with 70 oracles
# 9.740326881408691 s
# 15 th round with 75 oracles
# 10.136401176452637 s
# 16 th round with 80 oracles
# 10.813769102096558 s
# 17 th round with 85 oracles
# 12.092966794967651 s
# 18 th round with 90 oracles
# 12.41625189781189 s
# 19 th round with 95 oracles
# 12.471696138381958 s
# iter 8 finished
# 0 th round with 0 oracles
# 0.01267099380493164 s
# 1 th round with 5 oracles
# 0.6383440494537354 s
# 2 th round with 10 oracles
# 1.227781057357788 s
# 3 th round with 15 oracles
# 1.7480943202972412 s
# 4 th round with 20 oracles
# 2.289774179458618 s
# 5 th round with 25 oracles
# 3.0373902320861816 s
# 6 th round with 30 oracles
# 3.3444530963897705 s
# 7 th round with 35 oracles
# 3.889986991882324 s
# 8 th round with 40 oracles
# 4.513343095779419 s
# 9 th round with 45 oracles
# 5.321576118469238 s
# 10 th round with 50 oracles
# 5.816215991973877 s
# 11 th round with 55 oracles
# 6.233449935913086 s
# 12 th round with 60 oracles
# 6.872183799743652 s
# 13 th round with 65 oracles
# 7.535483121871948 s
# 14 th round with 70 oracles
# 8.309956073760986 s
# 15 th round with 75 oracles
# 8.392740249633789 s
# 16 th round with 80 oracles
# 8.987781047821045 s
# 17 th round with 85 oracles
# 10.53788709640503 s
# 18 th round with 90 oracles
# 10.313462018966675 s
# 19 th round with 95 oracles
# 10.876714944839478 s
# iter 9 finished
# 0 th round with 0 oracles
# 0.012238264083862305 s
# 1 th round with 5 oracles
# 0.6283929347991943 s
# 2 th round with 10 oracles
# 1.196293830871582 s
# 3 th round with 15 oracles
# 1.7693638801574707 s
# 4 th round with 20 oracles
# 2.3135628700256348 s
# 5 th round with 25 oracles
# 2.942736864089966 s
# 6 th round with 30 oracles
# 3.372330904006958 s
# 7 th round with 35 oracles
# 3.999177932739258 s
# 8 th round with 40 oracles
# 4.405916929244995 s
# 9 th round with 45 oracles
# 4.984464883804321 s
# 10 th round with 50 oracles
# 5.56524395942688 s
# 11 th round with 55 oracles
# 6.199084043502808 s
# 12 th round with 60 oracles
# 6.679560899734497 s
# 13 th round with 65 oracles
# 7.4126856327056885 s
# 14 th round with 70 oracles
# 7.918012857437134 s
# 15 th round with 75 oracles
# 9.118441104888916 s
# 16 th round with 80 oracles
# 9.056192874908447 s
# 17 th round with 85 oracles
# 9.559205770492554 s
# 18 th round with 90 oracles
# 10.049781799316406 s
# 19 th round with 95 oracles
# 10.378560066223145 s
# iter 10 finished
# 0 th round with 0 oracles
# 0.012314796447753906 s
# 1 th round with 5 oracles
# 0.5756640434265137 s
# 2 th round with 10 oracles
# 1.12483811378479 s
# 3 th round with 15 oracles
# 1.7229721546173096 s
# 4 th round with 20 oracles
# 2.3323450088500977 s
# 5 th round with 25 oracles
# 2.7620389461517334 s
# 6 th round with 30 oracles
# 3.3526761531829834 s
# 7 th round with 35 oracles
# 4.036048889160156 s
# 8 th round with 40 oracles
# 4.442584037780762 s
# 9 th round with 45 oracles
# 5.093498945236206 s
# 10 th round with 50 oracles
# 5.502869129180908 s
# 11 th round with 55 oracles
# 6.080977201461792 s
# 12 th round with 60 oracles
# 6.5729310512542725 s
# 13 th round with 65 oracles
# 7.194529056549072 s
# 14 th round with 70 oracles
# 7.857155084609985 s
# 15 th round with 75 oracles
# 8.273417234420776 s
# 16 th round with 80 oracles
# 9.276464223861694 s
# 17 th round with 85 oracles
# 9.514510154724121 s
# 18 th round with 90 oracles
# 10.20269513130188 s
# 19 th round with 95 oracles
# 10.72283411026001 s
# iter 11 finished
# 0 th round with 0 oracles
# 0.013522148132324219 s
# 1 th round with 5 oracles
# 0.6176130771636963 s
# 2 th round with 10 oracles
# 1.1267669200897217 s
# 3 th round with 15 oracles
# 1.6499450206756592 s
# 4 th round with 20 oracles
# 2.1616289615631104 s
# 5 th round with 25 oracles
# 2.723745107650757 s
# 6 th round with 30 oracles
# 3.321646213531494 s
# 7 th round with 35 oracles
# 4.028174877166748 s
# 8 th round with 40 oracles
# 4.443121910095215 s
# 9 th round with 45 oracles
# 5.192456960678101 s
# 10 th round with 50 oracles
# 5.762909173965454 s
# 11 th round with 55 oracles
# 6.05394983291626 s
# 12 th round with 60 oracles
# 6.6240620613098145 s
# 13 th round with 65 oracles
# 7.262757778167725 s
# 14 th round with 70 oracles
# 7.720294713973999 s
# 15 th round with 75 oracles
# 8.505260944366455 s
# 16 th round with 80 oracles
# 8.833871126174927 s
# 17 th round with 85 oracles
# 9.602323055267334 s
# 18 th round with 90 oracles
# 9.951876878738403 s
# 19 th round with 95 oracles
# 10.415044069290161 s
# iter 12 finished
# 0 th round with 0 oracles
# 0.013721227645874023 s
# 1 th round with 5 oracles
# 0.5997190475463867 s
# 2 th round with 10 oracles
# 1.2680041790008545 s
# 3 th round with 15 oracles
# 1.7371747493743896 s
# 4 th round with 20 oracles
# 2.2383458614349365 s
# 5 th round with 25 oracles
# 2.7937138080596924 s
# 6 th round with 30 oracles
# 3.319434881210327 s
# 7 th round with 35 oracles
# 3.9807169437408447 s
# 8 th round with 40 oracles
# 4.522623062133789 s
# 9 th round with 45 oracles
# 4.928384065628052 s
# 10 th round with 50 oracles
# 5.551723003387451 s
# 11 th round with 55 oracles
# 6.285836935043335 s
# 12 th round with 60 oracles
# 6.8214030265808105 s
# 13 th round with 65 oracles
# 7.354959011077881 s
# 14 th round with 70 oracles
# 7.615732908248901 s
# 15 th round with 75 oracles
# 8.507686853408813 s
# 16 th round with 80 oracles
# 8.836566925048828 s
# 17 th round with 85 oracles
# 9.453381061553955 s
# 18 th round with 90 oracles
# 10.007986068725586 s
# 19 th round with 95 oracles
# 10.848261833190918 s
# iter 13 finished
# 0 th round with 0 oracles
# 0.013382196426391602 s
# 1 th round with 5 oracles
# 0.6158819198608398 s
# 2 th round with 10 oracles
# 1.1482570171356201 s
# 3 th round with 15 oracles
# 1.6802828311920166 s
# 4 th round with 20 oracles
# 2.2582058906555176 s
# 5 th round with 25 oracles
# 2.777961015701294 s
# 6 th round with 30 oracles
# 3.3824880123138428 s
# 7 th round with 35 oracles
# 3.791977882385254 s
# 8 th round with 40 oracles
# 4.50029993057251 s
# 9 th round with 45 oracles
# 5.056037187576294 s
# 10 th round with 50 oracles
# 5.6237099170684814 s
# 11 th round with 55 oracles
# 6.068104982376099 s
# 12 th round with 60 oracles
# 6.712165832519531 s
# 13 th round with 65 oracles
# 7.3586790561676025 s
# 14 th round with 70 oracles
# 7.968095779418945 s
# 15 th round with 75 oracles
# 8.132086038589478 s
# 16 th round with 80 oracles
# 9.099008083343506 s
# 17 th round with 85 oracles
# 9.243167877197266 s
# 18 th round with 90 oracles
# 9.97629690170288 s
# 19 th round with 95 oracles
# 10.436568975448608 s
# iter 14 finished
# 0 th round with 0 oracles
# 0.012985706329345703 s
# 1 th round with 5 oracles
# 0.703300952911377 s
# 2 th round with 10 oracles
# 1.115427017211914 s
# 3 th round with 15 oracles
# 1.714845895767212 s
# 4 th round with 20 oracles
# 2.49088191986084 s
# 5 th round with 25 oracles
# 2.8210737705230713 s
# 6 th round with 30 oracles
# 3.3045408725738525 s
# 7 th round with 35 oracles
# 3.868328332901001 s
# 8 th round with 40 oracles
# 4.505497932434082 s
# 9 th round with 45 oracles
# 4.951841115951538 s
# 10 th round with 50 oracles
# 5.607530117034912 s
# 11 th round with 55 oracles
# 6.1190290451049805 s
# 12 th round with 60 oracles
# 7.135331153869629 s
# 13 th round with 65 oracles
# 7.25808572769165 s
# 14 th round with 70 oracles
# 7.7157042026519775 s
# 15 th round with 75 oracles
# 8.697083950042725 s
# 16 th round with 80 oracles
# 8.745758056640625 s
# 17 th round with 85 oracles
# 9.499823093414307 s
# 18 th round with 90 oracles
# 9.826555013656616 s
# 19 th round with 95 oracles
# 10.525915145874023 s
# iter 15 finished
# 0 th round with 0 oracles
# 0.014371156692504883 s
# 1 th round with 5 oracles
# 0.6103200912475586 s
# 2 th round with 10 oracles
# 1.1398780345916748 s
# 3 th round with 15 oracles
# 1.7111201286315918 s
# 4 th round with 20 oracles
# 2.282891035079956 s
# 5 th round with 25 oracles
# 2.7906548976898193 s
# 6 th round with 30 oracles
# 3.3426759243011475 s
# 7 th round with 35 oracles
# 3.8475229740142822 s
# 8 th round with 40 oracles
# 4.650613069534302 s
# 9 th round with 45 oracles
# 4.964418888092041 s
# 10 th round with 50 oracles
# 5.8185200691223145 s
# 11 th round with 55 oracles
# 5.965496063232422 s
# 12 th round with 60 oracles
# 6.6948840618133545 s
# 13 th round with 65 oracles
# 7.078348875045776 s
# 14 th round with 70 oracles
# 7.812211036682129 s
# 15 th round with 75 oracles
# 8.184000015258789 s
# 16 th round with 80 oracles
# 8.768641948699951 s
# 17 th round with 85 oracles
# 9.659593105316162 s
# 18 th round with 90 oracles
# 10.071330785751343 s
# 19 th round with 95 oracles
# 10.399170875549316 s
# iter 16 finished
# 0 th round with 0 oracles
# 0.01341104507446289 s
# 1 th round with 5 oracles
# 0.587691068649292 s
# 2 th round with 10 oracles
# 1.2673559188842773 s
# 3 th round with 15 oracles
# 1.6822700500488281 s
# 4 th round with 20 oracles
# 2.2497098445892334 s
# 5 th round with 25 oracles
# 2.7574098110198975 s
# 6 th round with 30 oracles
# 3.1791720390319824 s
# 7 th round with 35 oracles
# 3.8814539909362793 s
# 8 th round with 40 oracles
# 4.592423915863037 s
# 9 th round with 45 oracles
# 4.804516792297363 s
# 10 th round with 50 oracles
# 5.5646071434021 s
# 11 th round with 55 oracles
# 6.353758096694946 s
# 12 th round with 60 oracles
# 6.480929851531982 s
# 13 th round with 65 oracles
# 7.259743928909302 s
# 14 th round with 70 oracles
# 7.7213640213012695 s
# 15 th round with 75 oracles
# 8.398823022842407 s
# 16 th round with 80 oracles
# 8.830540180206299 s
# 17 th round with 85 oracles
# 9.333081007003784 s
# 18 th round with 90 oracles
# 10.345269203186035 s
# 19 th round with 95 oracles
# 10.792509317398071 s
# iter 17 finished
# 0 th round with 0 oracles
# 0.013988018035888672 s
# 1 th round with 5 oracles
# 0.5948569774627686 s
# 2 th round with 10 oracles
# 1.1008999347686768 s
# 3 th round with 15 oracles
# 1.7333970069885254 s
# 4 th round with 20 oracles
# 2.213435173034668 s
# 5 th round with 25 oracles
# 2.796602249145508 s
# 6 th round with 30 oracles
# 3.394902229309082 s
# 7 th round with 35 oracles
# 3.7762210369110107 s
# 8 th round with 40 oracles
# 4.584058046340942 s
# 9 th round with 45 oracles
# 5.159010887145996 s
# 10 th round with 50 oracles
# 5.704147815704346 s
# 11 th round with 55 oracles
# 6.055639028549194 s
# 12 th round with 60 oracles
# 7.241732120513916 s
# 13 th round with 65 oracles
# 7.7951366901397705 s
# 14 th round with 70 oracles
# 7.783056735992432 s
# 15 th round with 75 oracles
# 8.113950967788696 s
# 16 th round with 80 oracles
# 8.81114411354065 s
# 17 th round with 85 oracles
# 9.366162061691284 s
# 18 th round with 90 oracles
# 10.083838939666748 s
# 19 th round with 95 oracles
# 10.3891761302948 s
# iter 18 finished
# 0 th round with 0 oracles
# 0.014777898788452148 s
# 1 th round with 5 oracles
# 0.6028261184692383 s
# 2 th round with 10 oracles
# 1.3627121448516846 s
# 3 th round with 15 oracles
# 1.7181768417358398 s
# 4 th round with 20 oracles
# 2.29044508934021 s
# 5 th round with 25 oracles
# 2.7961668968200684 s
# 6 th round with 30 oracles
# 3.304932117462158 s
# 7 th round with 35 oracles
# 4.026668071746826 s
# 8 th round with 40 oracles
# 4.883782863616943 s
# 9 th round with 45 oracles
# 5.570750951766968 s
# 10 th round with 50 oracles
# 5.669100046157837 s
# 11 th round with 55 oracles
# 6.160946846008301 s
# 12 th round with 60 oracles
# 6.638242244720459 s
# 13 th round with 65 oracles
# 7.232165098190308 s
# 14 th round with 70 oracles
# 7.824069261550903 s
# 15 th round with 75 oracles
# 8.500828981399536 s
# 16 th round with 80 oracles
# 8.777136087417603 s
# 17 th round with 85 oracles
# 8.38590407371521 s
# 16 th round with 80 oracles
# 8.941956043243408 s
# 17 th round with 85 oracles
# 9.340532064437866 s
# 18 th round with 90 oracles
# 10.011493921279907 s
# 19 th round with 95 oracles
# 10.651288986206055 s
# iter 22 finished
# 0 th round with 0 oracles
# 0.015820026397705078 s
# 1 th round with 5 oracles
# 0.6086912155151367 s
# 2 th round with 10 oracles
# 1.2988178730010986 s
# 3 th round with 15 oracles
# 1.694490909576416 s
# 4 th round with 20 oracles
# 2.215135097503662 s
# 5 th round with 25 oracles
# 2.680548906326294 s
# 6 th round with 30 oracles
# 3.2385270595550537 s
# 7 th round with 35 oracles
# 3.882293939590454 s
# 8 th round with 40 oracles
# 4.506368160247803 s
# 9 th round with 45 oracles
# 4.926281929016113 s
# 10 th round with 50 oracles
# 5.616655111312866 s
# 11 th round with 55 oracles
# 6.235530853271484 s
# 12 th round with 60 oracles
# 6.607751131057739 s
# 13 th round with 65 oracles
# 7.1305882930755615 s
# 14 th round with 70 oracles
# 8.059420824050903 s
# 15 th round with 75 oracles
# 8.381435871124268 s
# 16 th round with 80 oracles
# 8.69500184059143 s
# 17 th round with 85 oracles
# 9.35792589187622 s
# 18 th round with 90 oracles
# 10.142269134521484 s
# 19 th round with 95 oracles
# 10.310886144638062 s
# iter 23 finished
# 0 th round with 0 oracles
# 0.016230106353759766 s
# 1 th round with 5 oracles
# 0.6134881973266602 s
# 2 th round with 10 oracles
# 1.1370809078216553 s
# 3 th round with 15 oracles
# 1.7116501331329346 s
# 4 th round with 20 oracles
# 2.1432900428771973 s
# 5 th round with 25 oracles
# 2.815092086791992 s
# 6 th round with 30 oracles
# 3.293705940246582 s
# 7 th round with 35 oracles
# 4.071495294570923 s
# 8 th round with 40 oracles
# 4.434138059616089 s
# 9 th round with 45 oracles
# 4.920508861541748 s
# 10 th round with 50 oracles
# 5.471714735031128 s
# 11 th round with 55 oracles
# 5.831880331039429 s
# 12 th round with 60 oracles
# 6.734884977340698 s
# 13 th round with 65 oracles
# 6.9794762134552 s
# 14 th round with 70 oracles
# 7.779086112976074 s
# 15 th round with 75 oracles
# 8.15726613998413 s
# 16 th round with 80 oracles
# 9.103878259658813 s
# 17 th round with 85 oracles
# 9.27516508102417 s
# 18 th round with 90 oracles
# 10.0419020652771 s
# 19 th round with 95 oracles
# 11.018941164016724 s
# iter 24 finished
# 0 th round with 0 oracles
# 0.017004966735839844 s
# 1 th round with 5 oracles
# 0.6053256988525391 s
# 2 th round with 10 oracles
# 1.1531341075897217 s
# 3 th round with 15 oracles
# 1.6625030040740967 s
# 4 th round with 20 oracles
# 2.170628070831299 s
# 5 th round with 25 oracles
# 2.7304940223693848 s
# 6 th round with 30 oracles
# 3.306626796722412 s
# 7 th round with 35 oracles
# 3.944639205932617 s
# 8 th round with 40 oracles
# 4.342925071716309 s
# 9 th round with 45 oracles
# 5.092677116394043 s
# 10 th round with 50 oracles
# 5.573177814483643 s
# 11 th round with 55 oracles
# 6.2039899826049805 s
# 12 th round with 60 oracles
# 6.497146129608154 s
# 13 th round with 65 oracles
# 7.308764934539795 s
# 12 th round with 60 oracles
# 6.439117193222046 s
# 13 th round with 65 oracles
# 7.192755937576294 s
# 14 th round with 70 oracles
# 7.690343141555786 s
# 15 th round with 75 oracles
# 8.212109088897705 s
# 16 th round with 80 oracles
# 9.095446109771729 s
# 17 th round with 85 oracles
# 9.391567945480347 s
# 18 th round with 90 oracles
# 9.849735260009766 s
# 19 th round with 95 oracles
# 10.482194900512695 s
# iter 28 finished
# 0 th round with 0 oracles
# 0.01768803596496582 s
# 1 th round with 5 oracles
# 0.6145989894866943 s
# 2 th round with 10 oracles
# 1.099492073059082 s
# 3 th round with 15 oracles
# 1.619312047958374 s
# 4 th round with 20 oracles
# 2.218813180923462 s
# 5 th round with 25 oracles
# 2.826190233230591 s
# 6 th round with 30 oracles
# 3.4424219131469727 s
# 7 th round with 35 oracles
# 3.805647134780884 s
# 8 th round with 40 oracles
# 4.4915831089019775 s
# 9 th round with 45 oracles
# 4.977835655212402 s
# 10 th round with 50 oracles
# 5.807034254074097 s
# 11 th round with 55 oracles
# 6.132061958312988 s
# 12 th round with 60 oracles
# 6.69632887840271 s
# 13 th round with 65 oracles
# 7.373878240585327 s
# 14 th round with 70 oracles
# 8.007293224334717 s
# 15 th round with 75 oracles
# 8.718171119689941 s
# 16 th round with 80 oracles
# 8.712282180786133 s
# 17 th round with 85 oracles
# 9.345909118652344 s
# 18 th round with 90 oracles
# 10.036745071411133 s
# 19 th round with 95 oracles
# 10.317260980606079 s
# iter 29 finished
# 0 th round with 0 oracles
# 0.016782045364379883 s
# 1 th round with 5 oracles
# 0.5941371917724609 s
# 2 th round with 10 oracles
# 1.2745490074157715 s
# 3 th round with 15 oracles
# 1.6745479106903076 s
# 4 th round with 20 oracles
# 2.1796982288360596 s
# 5 th round with 25 oracles
# 2.675028085708618 s
# 6 th round with 30 oracles
# 3.152395009994507 s
# 7 th round with 35 oracles
# 3.9586071968078613 s
# 8 th round with 40 oracles
# 4.471540212631226 s
# 9 th round with 45 oracles
# 4.928646802902222 s
# 10 th round with 50 oracles
# 5.62736701965332 s
# 11 th round with 55 oracles
# 6.033616065979004 s
# 12 th round with 60 oracles
# 6.866070032119751 s
# 13 th round with 65 oracles
# 7.195592880249023 s
# 14 th round with 70 oracles
# 7.754884958267212 s
# 15 th round with 75 oracles
# 8.40512204170227 s
# 16 th round with 80 oracles
# 8.64444899559021 s
# 17 th round with 85 oracles
# 9.443789005279541 s
# 18 th round with 90 oracles
# 9.850702047348022 s
# 19 th round with 95 oracles
# 10.741100072860718 s
# iter 30 finished
# 0 th round with 0 oracles
# 0.017161130905151367 s
# 1 th round with 5 oracles
# 0.5824880599975586 s
# 2 th round with 10 oracles
# 1.124927043914795 s
# 3 th round with 15 oracles
# 1.609523057937622 s
# 4 th round with 20 oracles
# 2.2240350246429443 s
# 5 th round with 25 oracles
# 2.8871102333068848 s
# 6 th round with 30 oracles
# 3.2627577781677246 s
# 7 th round with 35 oracles
# 3.804144859313965 s
# 8 th round with 40 oracles
# 4.52810001373291 s
# 9 th round with 45 oracles
# 5.136751174926758 s
# 10 th round with 50 oracles
# 7 th round with 35 oracles
# 3.8394367694854736 s
# 8 th round with 40 oracles
# 4.509570837020874 s
# 9 th round with 45 oracles
# 5.112878084182739 s
# 10 th round with 50 oracles
# 5.574622392654419 s
# 11 th round with 55 oracles
# 6.103576183319092 s
# 12 th round with 60 oracles
# 6.5547521114349365 s
# 13 th round with 65 oracles
# 7.159863233566284 s
# 14 th round with 70 oracles
# 7.515536069869995 s
# 15 th round with 75 oracles
# 8.265742778778076 s
# 16 th round with 80 oracles
# 8.588762044906616 s
# 17 th round with 85 oracles
# 9.771139144897461 s
# 18 th round with 90 oracles
# 9.806511878967285 s
# 19 th round with 95 oracles
# 10.360727787017822 s
# iter 37 finished
# 0 th round with 0 oracles
# 0.020596027374267578 s
# 1 th round with 5 oracles
# 0.6122140884399414 s
# 2 th round with 10 oracles
# 1.1460459232330322 s
# 3 th round with 15 oracles
# 1.6839139461517334 s
# 4 th round with 20 oracles
# 2.1352479457855225 s
# 5 th round with 25 oracles
# 2.8311471939086914 s
# 6 th round with 30 oracles
# 3.462290048599243 s
# 7 th round with 35 oracles
# 3.9086902141571045 s
# 8 th round with 40 oracles
# 4.279876947402954 s
# 9 th round with 45 oracles
# 4.993560075759888 s
# 10 th round with 50 oracles
# 5.547468185424805 s
# 11 th round with 55 oracles
# 6.012018918991089 s
# 12 th round with 60 oracles
# 6.8900909423828125 s
# 13 th round with 65 oracles
# 6.999902248382568 s
# 14 th round with 70 oracles
# 7.6748223304748535 s
# 15 th round with 75 oracles
# 8.092885971069336 s
# 16 th round with 80 oracles
# 8.808315753936768 s
# 17 th round with 85 oracles
# 9.190324306488037 s
# 18 th round with 90 oracles
# 9.919584035873413 s
# 19 th round with 95 oracles
# 10.77981686592102 s
# iter 38 finished
# 0 th round with 0 oracles
# 0.019852161407470703 s
# 1 th round with 5 oracles
# 0.7197771072387695 s
# 2 th round with 10 oracles
# 1.1206631660461426 s
# 3 th round with 15 oracles
# 1.7100331783294678 s
# 4 th round with 20 oracles
# 2.2422292232513428 s
# 5 th round with 25 oracles
# 2.6746811866760254 s
# 6 th round with 30 oracles
# 3.1745810508728027 s
# 7 th round with 35 oracles
# 3.697511911392212 s
# 8 th round with 40 oracles
# 4.577280044555664 s
# 9 th round with 45 oracles
# 4.936162948608398 s
# 10 th round with 50 oracles
# 5.499409914016724 s
# 11 th round with 55 oracles
# 6.08369517326355 s
# 12 th round with 60 oracles
# 6.600693941116333 s
# 13 th round with 65 oracles
# 7.032992124557495 s
# 14 th round with 70 oracles
# 8.091082096099854 s
# 15 th round with 75 oracles
# 8.39099383354187 s
# 16 th round with 80 oracles
# 8.638248920440674 s
# 17 th round with 85 oracles
# 9.39490294456482 s
# 18 th round with 90 oracles
# 9.70661997795105 s
# 19 th round with 95 oracles
# 10.518864870071411 s
# iter 39 finished
# 0 th round with 0 oracles
# 0.020688772201538086 s
# 1 th round with 5 oracles
# 0.6152980327606201 s
# 2 th round with 10 oracles
# 1.1816189289093018 s
# 3 th round with 15 oracles
# 1.694694995880127 s
# 4 th round with 20 oracles
# 2.228013753890991 s
# 5 th round with 25 oracles
# 2.7962541580200195 s
# 6 th round with 30 oracles
# 3.454704999923706 s
# 7 th round with 35 oracles
# 3.8033840656280518 s
# 8 th round with 40 oracles
# 4.334599256515503 s
# 9 th round with 45 oracles
# 5.074156999588013 s
# 10 th round with 50 oracles
# 5.548346757888794 s
# 11 th round with 55 oracles
# 5.984784841537476 s
# 12 th round with 60 oracles
# 6.616328001022339 s
# 13 th round with 65 oracles
# 7.000960111618042 s
# 14 th round with 70 oracles
# 7.7591753005981445 s
# 15 th round with 75 oracles
# 8.346832036972046 s
# 16 th round with 80 oracles
# 9.013022899627686 s
# 17 th round with 85 oracles
# 9.120439052581787 s
# 18 th round with 90 oracles
# 9.970286846160889 s
# 19 th round with 95 oracles
# 11.030317068099976 s
# iter 40 finished
# 0 th round with 0 oracles
# 0.021643877029418945 s
# 1 th round with 5 oracles
# 0.6125619411468506 s
# 2 th round with 10 oracles
# 1.141242265701294 s
# 3 th round with 15 oracles
# 1.688420057296753 s
# 4 th round with 20 oracles
# 2.20076584815979 s
# 5 th round with 25 oracles
# 2.6860568523406982 s
# 6 th round with 30 oracles
# 3.1646227836608887 s
# 7 th round with 35 oracles
# 3.8035330772399902 s
# 8 th round with 40 oracles
# 4.514956951141357 s
# 9 th round with 45 oracles
# 5.139879941940308 s
# 10 th round with 50 oracles
# 5.414092063903809 s
# 11 th round with 55 oracles
# 5.998545169830322 s
# 12 th round with 60 oracles
# 6.5479302406311035 s
# 13 th round with 65 oracles
# 7.12708306312561 s
# 14 th round with 70 oracles
# 7.715292930603027 s
# 15 th round with 75 oracles
# 8.281440019607544 s
# 16 th round with 80 oracles
# 8.517890214920044 s
# 17 th round with 85 oracles
# 9.92884612083435 s
# 18 th round with 90 oracles
# 9.686865091323853 s
# 19 th round with 95 oracles
# 10.460423946380615 s
# iter 41 finished
# 0 th round with 0 oracles
# 0.020034074783325195 s
# 1 th round with 5 oracles
# 0.5922517776489258 s
# 2 th round with 10 oracles
# 1.09975004196167 s
# 3 th round with 15 oracles
# 1.6331970691680908 s
# 4 th round with 20 oracles
# 2.2371938228607178 s
# 5 th round with 25 oracles
# 2.8305411338806152 s
# 6 th round with 30 oracles
# 3.334378957748413 s
# 7 th round with 35 oracles
# 3.730212688446045 s
# 8 th round with 40 oracles
# 4.451312065124512 s
# 9 th round with 45 oracles
# 4.985377073287964 s
# 10 th round with 50 oracles
# 5.516980886459351 s
# 11 th round with 55 oracles
# 6.003759145736694 s
# 12 th round with 60 oracles
# 6.543345928192139 s
# 13 th round with 65 oracles
# 7.177332878112793 s
# 14 th round with 70 oracles
# 7.472724914550781 s
# 15 th round with 75 oracles
# 8.151548862457275 s
# 16 th round with 80 oracles
# 8.725436925888062 s
# 17 th round with 85 oracles
# 9.232086658477783 s
# 18 th round with 90 oracles
# 9.9044349193573 s
# 19 th round with 95 oracles
# 10.654007911682129 s
# iter 42 finished
# 0 th round with 0 oracles
# 0.020197153091430664 s
# 1 th round with 5 oracles
# 0.5853712558746338 s
# 2 th round with 10 oracles
# 1.0929780006408691 s
# 0.5834519863128662 s
# 2 th round with 10 oracles
# 1.0962297916412354 s
# 3 th round with 15 oracles
# 1.662578821182251 s
# 4 th round with 20 oracles
# 2.2491238117218018 s
# 5 th round with 25 oracles
# 2.7502567768096924 s
# 6 th round with 30 oracles
# 3.1935818195343018 s
# 7 th round with 35 oracles
# 4.094878911972046 s
# 8 th round with 40 oracles
# 4.338705778121948 s
# 9 th round with 45 oracles
# 4.75478196144104 s
# 10 th round with 50 oracles
# 5.58854079246521 s
# 11 th round with 55 oracles
# 5.8359949588775635 s
# 12 th round with 60 oracles
# 7.0795488357543945 s
# 13 th round with 65 oracles
# 7.000671863555908 s
# 14 th round with 70 oracles
# 7.547010183334351 s
# 15 th round with 75 oracles
# 8.156506061553955 s
# 16 th round with 80 oracles
# 9.03435230255127 s
# 17 th round with 85 oracles
# 9.429083824157715 s
# 18 th round with 90 oracles
# 9.848564147949219 s
# 19 th round with 95 oracles
# 10.456695079803467 s
# iter 46 finished
# 0 th round with 0 oracles
# 0.021610021591186523 s
# 1 th round with 5 oracles
# 0.5802419185638428 s
# 2 th round with 10 oracles
# 1.1498620510101318 s
# 3 th round with 15 oracles
# 1.8355059623718262 s
# 4 th round with 20 oracles
# 2.2091798782348633 s
# 5 th round with 25 oracles
# 2.6906371116638184 s
# 6 th round with 30 oracles
# 3.1823770999908447 s
# 7 th round with 35 oracles
# 3.769789934158325 s
# 8 th round with 40 oracles
# 4.5379040241241455 s
# 9 th round with 45 oracles
# 5.002074718475342 s
# 10 th round with 50 oracles
# 5.667006969451904 s
# 11 th round with 55 oracles
# 5.9759838581085205 s
# 12 th round with 60 oracles
# 6.5279271602630615 s
# 13 th round with 65 oracles
# 6.935039043426514 s
# 14 th round with 70 oracles
# 7.9312849044799805 s
# 15 th round with 75 oracles
# 8.233703851699829 s
# 16 th round with 80 oracles
# 8.82518482208252 s
# 17 th round with 85 oracles
# 9.369778156280518 s
# 18 th round with 90 oracles
# 9.687539339065552 s
# 19 th round with 95 oracles
# 10.232027053833008 s
# iter 47 finished
# 0 th round with 0 oracles
# 0.022221088409423828 s
# 1 th round with 5 oracles
# 0.6202588081359863 s
# 2 th round with 10 oracles
# 1.1709609031677246 s
# 3 th round with 15 oracles
# 1.710472822189331 s
# 4 th round with 20 oracles
# 2.185194969177246 s
# 5 th round with 25 oracles
# 2.8090109825134277 s
# 6 th round with 30 oracles
# 3.3296148777008057 s
# 7 th round with 35 oracles
# 3.9872896671295166 s
# 8 th round with 40 oracles
# 4.316812038421631 s
# 9 th round with 45 oracles
# 4.958914041519165 s
# 10 th round with 50 oracles
# 5.5526556968688965 s
# 11 th round with 55 oracles
# 5.890763998031616 s
# 12 th round with 60 oracles
# 6.639270067214966 s
# 13 th round with 65 oracles
# 7.244714975357056 s
# 14 th round with 70 oracles
# 7.546534061431885 s
# 15 th round with 75 oracles
# 8.30639386177063 s
# 16 th round with 80 oracles
# 8.981109857559204 s
# 17 th round with 85 oracles
# 9.259458780288696 s
# 18 th round with 90 oracles
# 9.9860520362854 s
# 19 th round with 95 oracles
# 10.516655683517456 s
# iter 48 finished
# 0 th round with 0 oracles
# 0.022305011749267578 s
# 1 th round with 5 oracles
# 0.6236958503723145 s
# 2 th round with 10 oracles
# 1.3058617115020752 s
# 3 th round with 15 oracles
# 1.6724741458892822 s
# 4 th round with 20 oracles
# 2.1494100093841553 s
# 5 th round with 25 oracles
# 2.7125120162963867 s
# ...
# 12 th round with 60 oracles
# 6.6942620277404785 s
# 13 th round with 65 oracles
# 7.034698009490967 s
# 14 th round with 70 oracles
# 8.142224788665771 s
# 15 th round with 75 oracles
# 8.2552011013031 s
# 16 th round with 80 oracles
# 9.067783832550049 s
# 17 th round with 85 oracles
# 9.614825248718262 s
# 18 th round with 90 oracles
# 10.033025979995728 s
# 19 th round with 95 oracles
# 10.805761814117432 s
# iter 83 finished
# 0 th round with 0 oracles
# 0.032553911209106445 s
# 1 th round with 5 oracles
# 0.6245291233062744 s
# 2 th round with 10 oracles
# 1.134404182434082 s
# 3 th round with 15 oracles
# 1.6829469203948975 s
# 4 th round with 20 oracles
# 2.3243300914764404 s
# 5 th round with 25 oracles
# 2.8756980895996094 s
# 6 th round with 30 oracles
# 3.4604837894439697 s
# 7 th round with 35 oracles
# 4.0198142528533936 s
# 8 th round with 40 oracles
# 4.4159862995147705 s
# 9 th round with 45 oracles
# 5.056370973587036 s
# 10 th round with 50 oracles
# 5.783675909042358 s
# 11 th round with 55 oracles
# 6.377588987350464 s
# 12 th round with 60 oracles
# 6.934545040130615 s
# 13 th round with 65 oracles
# 7.200019121170044 s
# 14 th round with 70 oracles
# 7.913708925247192 s
# 15 th round with 75 oracles
# 8.362397909164429 s
# 16 th round with 80 oracles
# 9.125579833984375 s
# 17 th round with 85 oracles
# 9.602076768875122 s
# 18 th round with 90 oracles
# 10.147330045700073 s
# 19 th round with 95 oracles
# 10.605186223983765 s
# iter 84 finished
# 0 th round with 0 oracles
# 0.030788898468017578 s
# 1 th round with 5 oracles
# 0.6063308715820312 s
# 2 th round with 10 oracles
# 1.1615002155303955 s
# 3 th round with 15 oracles
# 1.8393328189849854 s
# 4 th round with 20 oracles
# 2.235102891921997 s
# 5 th round with 25 oracles
# 2.9637351036071777 s
# 6 th round with 30 oracles
# 3.3455140590667725 s
# 7 th round with 35 oracles
# 3.817192792892456 s
# 8 th round with 40 oracles
# 4.8677849769592285 s
# 9 th round with 45 oracles
# 5.582712888717651 s
# 10 th round with 50 oracles
# 5.740795850753784 s
# 11 th round with 55 oracles
# 6.256954908370972 s
# 12 th round with 60 oracles
# 6.438476800918579 s
# 13 th round with 65 oracles
# 7.500727653503418 s
# 14 th round with 70 oracles
# 7.873301029205322 s
# 15 th round with 75 oracles
# 8.107810974121094 s
# 16 th round with 80 oracles
# 9.109103202819824 s
# 17 th round with 85 oracles
# 9.36333417892456 s
# 18 th round with 90 oracles
# 9.863839149475098 s
# 19 th round with 95 oracles
# 10.428422927856445 s
# iter 85 finished
# 0 th round with 0 oracles
# 0.03243207931518555 s
# 1 th round with 5 oracles
# 0.6522707939147949 s
# 2 th round with 10 oracles
# 1.1690359115600586 s
# 3 th round with 15 oracles
# 1.7071630954742432 s
# 4 th round with 20 oracles
# 2.1972312927246094 s
# 5 th round with 25 oracles
# 2.7769789695739746 s
# 6 th round with 30 oracles
# 3.3019039630889893 s
# 7 th round with 35 oracles
# 4.023577928543091 s
# 8 th round with 40 oracles
# 4.3669538497924805 s
# 9 th round with 45 oracles
# 5.093753099441528 s
# 10 th round with 50 oracles
# 5.893024921417236 s
# 11 th round with 55 oracles
# 6.1995439529418945 s
# 12 th round with 60 oracles
# 6.819630146026611 s
# 13 th round with 65 oracles
# 7.390645980834961 s
# 14 th round with 70 oracles
# 7.900125980377197 s
# 15 th round with 75 oracles
# 8.586584091186523 s
# 16 th round with 80 oracles
# 9.056936979293823 s
# 17 th round with 85 oracles
# 9.57564902305603 s
# 18 th round with 90 oracles
# 10.170322179794312 s
# 19 th round with 95 oracles
# 10.469557046890259 s
# iter 86 finished
# 0 th round with 0 oracles
# 0.03322124481201172 s
# 1 th round with 5 oracles
# 0.63045334815979 s
# 2 th round with 10 oracles
# 1.1812629699707031 s
# 3 th round with 15 oracles
# 1.865211009979248 s
# 4 th round with 20 oracles
# 2.2335877418518066 s
# 5 th round with 25 oracles
# 2.767164945602417 s
# 6 th round with 30 oracles
# 3.3716378211975098 s
# 7 th round with 35 oracles
# 3.9924001693725586 s
# 8 th round with 40 oracles
# 4.5553460121154785 s
# 9 th round with 45 oracles
# 4.962490081787109 s
# 10 th round with 50 oracles
# 5.567211151123047 s
# 11 th round with 55 oracles
# 6.993171215057373 s
# 12 th round with 60 oracles
# 7.7020909786224365 s
# 13 th round with 65 oracles
# 8.772161960601807 s
# 14 th round with 70 oracles
# 8.67909288406372 s
# 15 th round with 75 oracles
# 8.019217014312744 s
# 16 th round with 80 oracles
# 8.847497940063477 s
# 17 th round with 85 oracles
# 9.326334953308105 s
# 18 th round with 90 oracles
# 9.453708171844482 s
# 19 th round with 95 oracles
# 10.519166946411133 s
# iter 87 finished
# 0 th round with 0 oracles
# 0.03162431716918945 s
# 1 th round with 5 oracles
# 0.5968639850616455 s
# 2 th round with 10 oracles
# 1.1213650703430176 s
# 3 th round with 15 oracles
# 1.7020001411437988 s
# 4 th round with 20 oracles
# 2.1726479530334473 s
# 5 th round with 25 oracles
# 2.667095184326172 s
# 6 th round with 30 oracles
# 3.1257619857788086 s
# 7 th round with 35 oracles
# 3.8895256519317627 s
# 8 th round with 40 oracles
# 4.347357988357544 s
# 9 th round with 45 oracles
# 4.822629928588867 s
# 10 th round with 50 oracles
# 5.4307379722595215 s
# 11 th round with 55 oracles
# 5.974459886550903 s
# 12 th round with 60 oracles
# 6.465457916259766 s
# 13 th round with 65 oracles
# 6.867810010910034 s
# 14 th round with 70 oracles
# 7.432977914810181 s
# 15 th round with 75 oracles
# 8.000020980834961 s
# 16 th round with 80 oracles
# 8.726948261260986 s
# 17 th round with 85 oracles
# 9.038356065750122 s
# 18 th round with 90 oracles
# 9.917477130889893 s
# 19 th round with 95 oracles
# 9.916680812835693 s
# iter 88 finished
# 0 th round with 0 oracles
# 0.03135800361633301 s
# iter 91 finished
# 0 th round with 0 oracles
# 0.031334877014160156 s
# 1 th round with 5 oracles
# 0.5757620334625244 s
# 2 th round with 10 oracles
# 1.1468102931976318 s
# 3 th round with 15 oracles
# 1.5854918956756592 s
# 4 th round with 20 oracles
# 2.1530559062957764 s
# 5 th round with 25 oracles
# 2.74884295463562 s
# 6 th round with 30 oracles
# 3.232762098312378 s
# 7 th round with 35 oracles
# 3.7575080394744873 s
# 8 th round with 40 oracles
# 4.243929147720337 s
# 9 th round with 45 oracles
# 4.859647989273071 s
# 10 th round with 50 oracles
# 5.435537815093994 s
# 11 th round with 55 oracles
# 5.972369909286499 s
# 12 th round with 60 oracles
# 6.9196741580963135 s
# 13 th round with 65 oracles
# 8.678086996078491 s
# 14 th round with 70 oracles
# 9.570414066314697 s
# 15 th round with 75 oracles
# 8.432224988937378 s
# 16 th round with 80 oracles
# 8.400187015533447 s
# 17 th round with 85 oracles
# 7.939513683319092 s
# 18 th round with 90 oracles
# 8.836684942245483 s
# 19 th round with 95 oracles
# 9.240391969680786 s
# iter 92 finished
# 0 th round with 0 oracles
# 0.03013300895690918 s
# 1 th round with 5 oracles
# 0.5256772041320801 s
# 2 th round with 10 oracles
# 0.973639965057373 s
# 3 th round with 15 oracles
# 1.6243457794189453 s
# 4 th round with 20 oracles
# 1.9117088317871094 s
# 5 th round with 25 oracles
# 2.3334970474243164 s
# 6 th round with 30 oracles
# 2.9846370220184326 s
# 7 th round with 35 oracles
# 3.316155195236206 s
# 8 th round with 40 oracles
# 3.840930938720703 s
# 9 th round with 45 oracles
# 4.208745002746582 s
# 10 th round with 50 oracles
# 4.715241193771362 s
# 11 th round with 55 oracles
# 5.281397104263306 s
# 12 th round with 60 oracles
# 5.730087041854858 s
# 13 th round with 65 oracles
# 6.169971227645874 s
# 14 th round with 70 oracles
# 6.918858051300049 s
# 15 th round with 75 oracles
# 7.076765060424805 s
# 16 th round with 80 oracles
# 7.580991983413696 s
# 17 th round with 85 oracles
# 8.138792991638184 s
# 18 th round with 90 oracles
# 8.751854181289673 s
# 19 th round with 95 oracles
# 9.656679153442383 s
# iter 93 finished
# 0 th round with 0 oracles
# 0.029735326766967773 s
# 1 th round with 5 oracles
# 0.5479850769042969 s
# 2 th round with 10 oracles
# 1.0128281116485596 s
# 3 th round with 15 oracles
# 1.4619669914245605 s
# 4 th round with 20 oracles
# 1.956045150756836 s
# 5 th round with 25 oracles
# 2.4814889430999756 s
# 6 th round with 30 oracles
# 2.812772035598755 s
# 7 th round with 35 oracles
# 3.3692209720611572 s
# 8 th round with 40 oracles
# 3.828739881515503 s
# 9 th round with 45 oracles
# 4.1828789710998535 s
# 10 th round with 50 oracles
# 4.8834381103515625 s
# 11 th round with 55 oracles
# 5.150943994522095 s
# 12 th round with 60 oracles
# 5.766674280166626 s
# 13 th round with 65 oracles
# 5.936988115310669 s
# 14 th round with 70 oracles
# 6.516969919204712 s
# 15 th round with 75 oracles
# 7.286710023880005 s
# 16 th round with 80 oracles
# 8.304460048675537 s
# 17 th round with 85 oracles
# 8.038751363754272 s
# 18 th round with 90 oracles
# 8.793897151947021 s
# 19 th round with 95 oracles
# 11.070940017700195 s
# iter 94 finished
# 0 th round with 0 oracles
# 0.034120798110961914 s
# 1 th round with 5 oracles
# 0.6422219276428223 s
# 2 th round with 10 oracles
# 1.2641181945800781 s
# 3 th round with 15 oracles
# 2.3599753379821777 s
# 4 th round with 20 oracles
# 2.6949918270111084 s
# 5 th round with 25 oracles
# 3.4980311393737793 s
# 6 th round with 30 oracles
# 4.391535997390747 s
# 7 th round with 35 oracles
# 4.942788124084473 s
# 8 th round with 40 oracles
# 5.633860111236572 s
# 9 th round with 45 oracles
# 5.23000693321228 s
# 10 th round with 50 oracles
# 5.295771837234497 s
# 11 th round with 55 oracles
# 5.775357961654663 s
# 12 th round with 60 oracles
# 6.244439125061035 s
# 13 th round with 65 oracles
# 6.532380104064941 s
# 14 th round with 70 oracles
# 7.3199169635772705 s
# 15 th round with 75 oracles
# 7.668367147445679 s
# 16 th round with 80 oracles
# 8.26673173904419 s
# 17 th round with 85 oracles
# 8.951855182647705 s
# 18 th round with 90 oracles
# 9.432562828063965 s
# 19 th round with 95 oracles
# 9.84741497039795 s
# iter 95 finished
# 0 th round with 0 oracles
# 0.033087968826293945 s
# 1 th round with 5 oracles
# 0.5756139755249023 s
# 2 th round with 10 oracles
# 1.0968849658966064 s
# 3 th round with 15 oracles
# 1.5617649555206299 s
# 4 th round with 20 oracles
# 2.071943998336792 s
# 5 th round with 25 oracles
# 2.6035900115966797 s
# 6 th round with 30 oracles
# 3.0524959564208984 s
# 7 th round with 35 oracles
# 3.6777069568634033 s
# 8 th round with 40 oracles
# 3.958739995956421 s
# 9 th round with 45 oracles
# 4.554173946380615 s
# 10 th round with 50 oracles
# 5.145967245101929 s
# 11 th round with 55 oracles
# 5.468760013580322 s
# 12 th round with 60 oracles
# 6.193676948547363 s
# 13 th round with 65 oracles
# 6.491443872451782 s
# 14 th round with 70 oracles
# 7.131266117095947 s
# 15 th round with 75 oracles
# 7.717144966125488 s
# 16 th round with 80 oracles
# 8.089121103286743 s
# 17 th round with 85 oracles
# 8.47901201248169 s
# 18 th round with 90 oracles
# 9.188442945480347 s
# 19 th round with 95 oracles
# 9.842411994934082 s
# iter 96 finished
# 0 th round with 0 oracles
# 0.03334403038024902 s
# 1 th round with 5 oracles
# 0.557607889175415 s
# 2 th round with 10 oracles
# 1.074106216430664 s
# 3 th round with 15 oracles
# 1.7010760307312012 s
# 4 th round with 20 oracles
# 2.0718588829040527 s
# 5 th round with 25 oracles
# 2.5639748573303223 s
# 6 th round with 30 oracles
# 3.0317020416259766 s
# 7 th round with 35 oracles
# 3.46081280708313 s
# 8 th round with 40 oracles
# 4.317411184310913 s
# 9 th round with 45 oracles
# 4.5800299644470215 s
# 10 th round with 50 oracles
# 5.027672052383423 s
# 11 th round with 55 oracles
# 5.905617952346802 s
# 12 th round with 60 oracles
# 6.243617057800293 s
# 13 th round with 65 oracles
# 6.823071002960205 s
# 14 th round with 70 oracles
# 8.049452066421509 s
# 15 th round with 75 oracles
# 7.362040996551514 s
# 16 th round with 80 oracles
# 7.832113981246948 s
# 17 th round with 85 oracles
# 12.932080030441284 s
# 18 th round with 90 oracles
# 10.582765817642212 s
# 19 th round with 95 oracles
# 10.812549829483032 s
# iter 97 finished
# 0 th round with 0 oracles
# 0.041170358657836914 s
# 1 th round with 5 oracles
# 0.6262447834014893 s
# 2 th round with 10 oracles
# 1.1606872081756592 s
# 3 th round with 15 oracles
# 1.7387678623199463 s
# 4 th round with 20 oracles
# 2.361459970474243 s
# 5 th round with 25 oracles
# 2.754002094268799 s
# 6 th round with 30 oracles
# 3.3700151443481445 s
# 7 th round with 35 oracles
# 3.92250394821167 s
# 8 th round with 40 oracles
# 4.54169225692749 s
# 9 th round with 45 oracles
# 4.930660724639893 s
# 10 th round with 50 oracles
# 6.022199869155884 s
# 11 th round with 55 oracles
# 7.138306140899658 s
# 12 th round with 60 oracles
# 7.183874130249023 s
# 13 th round with 65 oracles
# 7.519767999649048 s
# 14 th round with 70 oracles
# 7.7299699783325195 s
# 15 th round with 75 oracles
# 8.88952088356018 s
# 16 th round with 80 oracles
# 9.19119381904602 s
# 17 th round with 85 oracles
# 9.868802070617676 s
# 18 th round with 90 oracles
# 10.374831914901733 s
# 19 th round with 95 oracles
# 10.961017847061157 s
# iter 98 finished
# 0 th round with 0 oracles
# 0.03313779830932617 s
# 1 th round with 5 oracles
# 0.6151201725006104 s
# 2 th round with 10 oracles
# 1.1418969631195068 s
# 3 th round with 15 oracles
# 1.8474071025848389 s
# 4 th round with 20 oracles
# 2.3770036697387695 s
# 5 th round with 25 oracles
# 2.8468360900878906 s
# 6 th round with 30 oracles
# 3.473613739013672 s
# 7 th round with 35 oracles
# 3.956049919128418 s
# 8 th round with 40 oracles
# 4.802067041397095 s
# 9 th round with 45 oracles
# 5.244186878204346 s
# 10 th round with 50 oracles
# 5.747179985046387 s
# 11 th round with 55 oracles
# 6.461584091186523 s
# 12 th round with 60 oracles
# 6.9114251136779785 s
# 13 th round with 65 oracles
# 7.465955018997192 s
# 14 th round with 70 oracles
# 8.077573776245117 s
# 15 th round with 75 oracles
# 7.545718193054199 s
# 16 th round with 80 oracles
# 7.864290714263916 s
# 17 th round with 85 oracles
# 8.692039966583252 s
# 18 th round with 90 oracles
# 8.787152767181396 s
# 19 th round with 95 oracles
# 10.715280055999756 s
# iter 99 finished
# 11215.87719130516

# %%
with open("p001_q001_piover100.pkl", "rb") as f:
    counts_lists = pickle.load(f)

# %%
hit_lists = []
for i in range(max_iter):
    hit_list = make_hit_list(counts_lists[i])
    # print(hit_list)
    hit_lists.append(hit_list)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
shots = 8192
qr = QuantumRegister(nbit+1)
mit_pattern = [[i] for i in range(nbit+1)]
meas_calibs, state_labels = tensored_meas_cal(mit_pattern=mit_pattern, qr=qr, circlabel='mcal')
meas_fitters = []
for i in range(max_iter):
    job = execute(meas_calibs, backend=Aer.get_backend('qasm_simulator'), shots=shots, noise_model=noise_model, seed_transpiler=i, seed_simulator=i)
    cal_results = job.result()
    meas_fitter = TensoredMeasFitter(cal_results, mit_pattern=mit_pattern)
    meas_fitters.append(meas_fitter)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
ts_sgs_list = []
mit_hit_lists = []
for i, counts_list in enumerate(counts_lists):
    ts_sgs = []
    mit_counts_list = []
    for counts in counts_list:
        t1 = time.time()
        meas_filter = InvSGS(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        x_tilde = meas_filter.apply(counts, silent=True)
        t2 = time.time()
        ts_sgs.append(t2 - t1)
        mit_counts_list.append(x_tilde)
    mit_hit_list = make_hit_list(mit_counts_list)
    mit_hit_lists.append(mit_hit_list)
    ts_sgs_list.append(ts_sgs)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("mit_hit_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_lists, f)
with open("ts_mit_hit_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_sgs_list, f)

# %%
ts_lm0_sgs_list = []
mit_hit_S_lm_0_lists = []
for i, counts_list in enumerate(counts_lists):
    ts_lm0_sgs = []
    x_tilde_S_lm_0_list = []
    for counts in counts_list:
        meas_filter = InvSLM0SGS(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        t1 = time.time()
        x_tilde = meas_filter.apply(counts, silent=True)
        t2 = time.time()
        ts_lm0_sgs.append(t2 - t1)
        x_tilde_S_lm_0_list.append(x_tilde)
    mit_hit_S_lm_0_list = make_hit_list(x_tilde_S_lm_0_list)
    mit_hit_S_lm_0_lists.append(mit_hit_S_lm_0_list)
    ts_lm0_sgs_list.append(ts_lm0_sgs)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("mit_hit_S_lm_0_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_S_lm_0_lists, f)
with open("ts_lm0_sgs_list_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_lm0_sgs_list, f)

# %%
ts_mooney100_list = []
mit_hit_mooney100_lists = []
for i, counts_list in enumerate(counts_lists):
    ts_mooney100 = []
    x_tilde_mooney_list = []
    for counts in counts_list:
        meas_filter = MooneyEtal(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        t1 = time.time()
        x_tilde = meas_filter.apply(counts, threshold=1/100, silent=True)
        t2 = time.time()
        ts_mooney100.append(t2 - t1)
        x_tilde_mooney_list.append(x_tilde)
    mit_hit_mooney100_list = make_hit_list(x_tilde_mooney_list)
    mit_hit_mooney100_lists.append(mit_hit_mooney100_list)
    ts_mooney100_list.append(ts_mooney100)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 10 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 11 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 17 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 28 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 29 finished
# iter 30 finished
# iter 31 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 32 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 33 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 34 finished
# iter 35 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 36 finished
# iter 37 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 38 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 39 finished
# iter 40 finished
# iter 41 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 51 finished
# iter 52 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 53 finished
# iter 54 finished
# iter 55 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 56 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 62 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 76 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 84 finished
# iter 85 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 86 finished
# iter 87 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 88 finished
# iter 89 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("mit_hit_mooney100_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_mooney100_lists, f)
with open("ts_mooney100_list_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_mooney100_list, f)

# %%
ts_mooney10_list = []
mit_hit_mooney10_lists = []
for i, counts_list in enumerate(counts_lists):
    ts_mooney10 = []
    x_tilde_mooney_list = []
    for counts in counts_list:
        meas_filter = MooneyEtal(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        t1 = time.time()
        x_tilde = meas_filter.apply(counts, threshold=1/10, silent=True)
        t2 = time.time()
        ts_mooney10.append(t2 - t1)
        x_tilde_mooney_list.append(x_tilde)
    mit_hit_mooney10_list = make_hit_list(x_tilde_mooney_list)
    mit_hit_mooney10_lists.append(mit_hit_mooney10_list)
    ts_mooney10_list.append(ts_mooney10)
    print("iter", i, "finished")
# Out:
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 0 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 1 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 2 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 3 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 4 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 5 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 6 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 7 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 8 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 9 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 10 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 11 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 12 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 13 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 14 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 15 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 16 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 17 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 18 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 19 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 20 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 21 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 22 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 23 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 24 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 25 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 26 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 27 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 28 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 29 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 30 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 31 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 32 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 33 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 34 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# ...
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 88 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 89 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 90 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 91 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 92 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 93 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 94 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 95 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 96 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 97 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 98 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 99 finished

# %%
with open("mit_hit_mooney10_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_mooney10_lists, f)
with open("ts_mooney10_list_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_mooney10_list, f)

# %%
ts_scipy_list = []
mit_hit_S_SciPy_lists = []
for i, counts_list in enumerate(counts_lists):
    x_tilde_S_SciPy_list = []
    ts_scipy = []
    for counts in counts_list:
        meas_filter = InvSSciPy(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        t1 = time.time()
        x_tilde = meas_filter.apply(counts, silent=True)
        t2 = time.time()
        ts_scipy.append(t2 - t1)
        x_tilde_S_SciPy_list.append(x_tilde)
    mit_hit_S_SciPy_list = make_hit_list(x_tilde_S_SciPy_list)
    mit_hit_S_SciPy_lists.append(mit_hit_S_SciPy_list)
    ts_scipy_list.append(ts_scipy)
    print("iter", i, "finished")
# Out:
# iter 0 finished
# iter 1 finished
# iter 2 finished
# iter 3 finished
# iter 4 finished
# iter 5 finished
# iter 6 finished
# iter 7 finished
# iter 8 finished
# iter 9 finished
# iter 10 finished
# iter 11 finished
# iter 12 finished
# iter 13 finished
# iter 14 finished
# iter 15 finished
# iter 16 finished
# iter 17 finished
# iter 18 finished
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# iter 24 finished
# iter 25 finished
# iter 26 finished
# iter 27 finished
# iter 28 finished
# iter 29 finished
# iter 30 finished
# iter 31 finished
# iter 32 finished
# iter 33 finished
# iter 34 finished
# iter 35 finished
# iter 36 finished
# iter 37 finished
# iter 38 finished
# iter 39 finished
# iter 40 finished
# iter 41 finished
# iter 42 finished
# iter 43 finished
# iter 44 finished
# iter 45 finished
# iter 46 finished
# iter 47 finished
# iter 48 finished
# iter 49 finished
# iter 50 finished
# iter 51 finished
# iter 52 finished
# iter 53 finished
# iter 54 finished
# iter 55 finished
# iter 56 finished
# iter 57 finished
# iter 58 finished
# iter 59 finished
# iter 60 finished
# iter 61 finished
# iter 62 finished
# iter 63 finished
# iter 64 finished
# iter 65 finished
# iter 66 finished
# iter 67 finished
# iter 68 finished
# iter 69 finished
# iter 70 finished
# iter 71 finished
# iter 72 finished
# iter 73 finished
# iter 74 finished
# iter 75 finished
# iter 76 finished
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# iter 82 finished
# iter 83 finished
# iter 84 finished
# iter 85 finished
# iter 86 finished
# iter 87 finished
# iter 88 finished
# iter 89 finished
# iter 90 finished
# iter 91 finished
# iter 92 finished
# iter 93 finished
# iter 94 finished
# iter 95 finished
# iter 96 finished
# iter 97 finished
# iter 98 finished
# iter 99 finished

# %%
with open("mit_hit_S_SciPy_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_S_SciPy_lists, f)
with open("ts_scipy_list_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_scipy_list, f)

# %%
ts_scipy_sgs_list = []
mit_hit_S_SciPy_SGS_lists = []
for i, counts_list in enumerate(counts_lists):
    ts_scipy_sgs = []
    x_tilde_S_SciPy_SGS_list = []
    for counts in counts_list:
        meas_filter = InvSSciPySGS(nbit+1, meas_fitters[i].cal_matrices, mit_pattern)
        t1 = time.time()
        x_tilde = meas_filter.apply(counts, silent=True)
        t2 = time.time()
        ts_scipy_sgs.append(t2 - t1)
        x_tilde_S_SciPy_SGS_list.append(x_tilde)
    mit_hit_S_SciPy_SGS_list = make_hit_list(x_tilde_S_SciPy_SGS_list)
    mit_hit_S_SciPy_SGS_lists.append(mit_hit_S_SciPy_SGS_list)
    ts_scipy_sgs_list.append(ts_scipy_sgs)
    print("iter", i, "finished")
# Out:
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 0 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 1 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 2 finished
# iter 3 finished
# iter 4 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 5 finished
# iter 6 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 7 finished
# iter 8 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 9 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 10 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 11 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 12 finished
# iter 13 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 14 finished
# iter 15 finished
# iter 16 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 17 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 18 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 19 finished
# iter 20 finished
# iter 21 finished
# iter 22 finished
# iter 23 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 24 finished
# iter 25 finished
# iter 26 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 27 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 28 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 29 finished
# iter 30 finished
# iter 31 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 32 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 33 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 34 finished
# iter 35 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 36 finished
# iter 37 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 38 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 39 finished
# iter 40 finished
# iter 41 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 42 finished
# iter 43 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 44 finished
# iter 45 finished
# iter 46 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 47 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 48 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 49 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 50 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 51 finished
# iter 52 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 53 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 54 finished
# iter 55 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 56 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 57 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 58 finished
# iter 59 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 60 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 61 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 62 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 63 finished
# iter 64 finished
# iter 65 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 66 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 67 finished
# iter 68 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 69 finished
# iter 70 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 71 finished
# iter 72 finished
# iter 73 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 74 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 75 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 76 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 77 finished
# iter 78 finished
# iter 79 finished
# iter 80 finished
# iter 81 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 82 finished
# iter 83 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 84 finished
# iter 85 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 86 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 87 finished
# iter 88 finished
# iter 89 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 90 finished
# iter 91 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 92 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 93 finished
# iter 94 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 95 finished
# iter 96 finished
# iter 97 finished
# accumulator is positive, we might even ignoring the necessal positive values.
# iter 98 finished
# iter 99 finished

# %%
with open("mit_hit_S_SciPy_SGS_lists_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(mit_hit_S_SciPy_SGS_lists, f)
with open("ts_scipy_sgs_list_p001_q001_piover100.pkl", "wb") as f:
    pickle.dump(ts_scipy_sgs_list, f)

# %%
# with open("mit_hit_lists_p001_q001_piover100.pkl", "rb") as f:
#     mit_hit_lists = pickle.load(f)

# %%
divide = len(number_grover_list)
# number_grover_list = [10 * i for i in range(10)]
plt.plot(np.linspace(0,number_grover_list[-1], divide), 
         100 * np.cos(2 * np.linspace(0,number_grover_list[-1], divide) * np.arccos(np.sqrt(discretizedResult))) ** 2, 
         label="theoretical curve", color="C7")
plt.plot(number_grover_list, hit_lists[-1], marker="o", label="results with readout error", color="C0")
plt.plot(number_grover_list, mit_hit_lists[-1], marker="x", label="mitigated results", color="C1")
plt.plot(number_grover_list, mit_hit_S_lm_0_lists[-1], marker="v", label="mitigated results (+S +LM0)", color="C2")
plt.plot(number_grover_list, mit_hit_mooney10_lists[-1], marker="*", label="Mooney et al. (t = 10)", color="C3")
plt.plot(number_grover_list, mit_hit_mooney100_lists[-1], marker="*", label="Mooney et al. (t = 100)", color="C4")
plt.plot(number_grover_list, mit_hit_S_SciPy_lists[-1], marker="*", label="SciPy", color="C5")
plt.plot(number_grover_list, mit_hit_S_SciPy_SGS_lists[-1], marker="*", label="SciPy + SGS", color="C6")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
plt.title("10qubit, p(0->1): 0.01, p(1->0): 0.01")
plt.xlabel("number of grover iterations $m$")
plt.ylabel("number of shots for $|00...0>$")
# Out:
# Text(0, 0.5, 'number of shots for $|00...0>$')

# %% [markdown]
# # Afterwards

# %%
# del counts_lists

# %%
thetaCandidate_lists = []
thetaCandidate_mit_lists = []
thetaCandidate_mit_S_lm_0_lists = []
thetaCandidate_mit_mooney100_lists = []
thetaCandidate_mit_mooney10_lists = []
thetaCandidate_mit_S_SciPy_lists = []
thetaCandidate_mit_S_SciPy_SGS_lists = []
for hit_list, mit_hit_list, mit_hit_S_lm_0_list, mit_hit_mooney10_list, mit_hit_mooney100_list, mit_hit_S_SciPy_list, mit_hit_S_SciPy_SGS_list in\
    zip(hit_lists, mit_hit_lists, mit_hit_S_lm_0_lists, mit_hit_mooney10_lists, mit_hit_mooney100_lists, mit_hit_S_SciPy_lists, mit_hit_S_SciPy_SGS_lists):
    sin_hit_list = [100 - h for h in hit_list]
    sin_mit_hit_list = [100 - h for h in mit_hit_list]
    sin_mit_hit_S_lm_0_list = [100 - h for h in mit_hit_S_lm_0_list]
    sin_mit_hit_mooney100_list = [100 - h for h in mit_hit_mooney100_list]
    sin_mit_hit_mooney10_list = [100 - h for h in mit_hit_mooney10_list]
    sin_mit_hit_S_SciPy_list = [100 - h for h in mit_hit_S_SciPy_list]
    sin_mit_hit_S_SciPy_SGS_list = [100 - h for h in mit_hit_S_SciPy_SGS_list]

    thetaCandidate_list = calculate_theta(
        sin_hit_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_list = calculate_theta(
        sin_mit_hit_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_S_lm_0_list = calculate_theta(
        sin_mit_hit_S_lm_0_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_mooney100_list = calculate_theta(
        sin_mit_hit_mooney100_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_mooney10_list = calculate_theta(
        sin_mit_hit_mooney10_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_S_SciPy_list = calculate_theta(
        sin_mit_hit_S_SciPy_list, number_grover_list, shots_list)  # list of estimated theta values
    thetaCandidate_mit_S_SciPy_SGS_list = calculate_theta(
        sin_mit_hit_S_SciPy_SGS_list, number_grover_list, shots_list)  # list of estimated theta values

    thetaCandidate_lists.append(thetaCandidate_list)
    thetaCandidate_mit_lists.append(thetaCandidate_mit_list)
    thetaCandidate_mit_S_lm_0_lists.append(thetaCandidate_mit_S_lm_0_list)
    thetaCandidate_mit_mooney100_lists.append(thetaCandidate_mit_mooney100_list)
    thetaCandidate_mit_mooney10_lists.append(thetaCandidate_mit_mooney10_list)
    thetaCandidate_mit_S_SciPy_lists.append(thetaCandidate_mit_S_SciPy_list)
    thetaCandidate_mit_S_SciPy_SGS_lists.append(thetaCandidate_mit_S_SciPy_SGS_list)
# Out:
# ../libmitigation/lib_grover.py:229: RuntimeWarning: invalid value encountered in sqrt
#   theta = np.arcsin(np.sqrt(p))  # search theta

# %%
thetaCandidate_list, thetaCandidate_list_stddev = np.mean(np.array(thetaCandidate_lists), axis=0), np.std(np.array(thetaCandidate_lists), axis=0)

# %%
thetaCandidate_mit_list, thetaCandidate_mit_list_stddev = np.mean(np.array(thetaCandidate_mit_lists), axis=0), np.std(np.array(thetaCandidate_mit_lists), axis=0)

# %%
thetaCandidate_mit_S_lm_0_list, thetaCandidate_mit_S_lm_0_list_stddev = np.mean(np.array(thetaCandidate_mit_S_lm_0_lists), axis=0) , np.std(np.array(thetaCandidate_mit_S_lm_0_lists), axis=0)

# %%
thetaCandidate_mit_mooney100_list, thetaCandidate_mit_mooney100_list_stddev = np.mean(np.array(thetaCandidate_mit_mooney100_lists), axis=0), np.std(np.array(thetaCandidate_mit_mooney100_lists), axis=0)

# %%
thetaCandidate_mit_mooney10_list, thetaCandidate_mit_mooney10_list_stddev = np.mean(np.array(thetaCandidate_mit_mooney10_lists), axis=0), np.std(np.array(thetaCandidate_mit_mooney10_lists), axis=0)

# %%
thetaCandidate_mit_S_SciPy_list, thetaCandidate_mit_S_SciPy_list_stddev = np.mean(np.array(thetaCandidate_mit_S_SciPy_lists), axis=0), np.std(np.array(thetaCandidate_mit_S_SciPy_lists), axis=0)

# %%
thetaCandidate_mit_S_SciPy_SGS_list, thetaCandidate_mit_S_SciPy_SGS_list_stddev = np.mean(np.array(thetaCandidate_mit_S_SciPy_SGS_lists), axis=0), np.std(np.array(thetaCandidate_mit_S_SciPy_SGS_lists), axis=0)

# %%
error_list = np.abs(np.sin(thetaCandidate_list)**2 - discretizedResult)  # list of estimation errors
error_mit_list = np.abs(np.sin(thetaCandidate_mit_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_lm_0_list = np.abs(np.sin(thetaCandidate_mit_S_lm_0_list)**2 - discretizedResult)  # list of estimation errors
error_mit_mooney100_list = np.abs(np.sin(thetaCandidate_mit_mooney100_list)**2 - discretizedResult)  # list of estimation errors
error_mit_mooney10_list = np.abs(np.sin(thetaCandidate_mit_mooney10_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_SciPy_list = np.abs(np.sin(thetaCandidate_mit_S_SciPy_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_SciPy_SGS_list = np.abs(np.sin(thetaCandidate_mit_S_SciPy_SGS_list)**2 - discretizedResult)  # list of estimation errors

# %%
OracleCall_list = []  # list of number of oracle calls
ErrorCramérRao_list = []  # list of Cramér-Rao lower bound
for i in range(len(number_grover_list)):
    OracleCall_list.append(
        CalcNumberOracleCalls(i, shots_list, number_grover_list))
    ErrorCramérRao_list.append(
        CalcErrorCramérRao(i, shots_list, discretizedResult, number_grover_list))

# %%
plt.clf()
p = plt.loglog( OracleCall_list, ErrorCramérRao_list)
p0 = plt.loglog( OracleCall_list, error_list, 'o', markersize=3)
p1 = plt.loglog( OracleCall_list, error_mit_list, '*', color='C4', markersize=6)
p2 = plt.loglog( OracleCall_list, error_mit_mooney100_list, 'x', color='C2', markersize=4)
p4 = plt.loglog( OracleCall_list, error_mit_mooney10_list, 'x', color='C5', markersize=4)
p5 = plt.loglog( OracleCall_list, error_mit_S_SciPy_list, 'v', color='C6', markersize=2)
p6 = plt.loglog( OracleCall_list, error_mit_S_SciPy_SGS_list, 'v', color='C7', markersize=2)
p3 = plt.loglog( OracleCall_list, error_mit_S_lm_0_list, 'v', color='C3', markersize=2)

plt.title("10qubit, p(0|1)=p(1|0)=0.01, b_max=π/100")
plt.xlim(OracleCall_list[0]*0.9, OracleCall_list[-1]*1.5)
plt.xlabel("Number of oracle calls")
plt.ylim(0.00000001, 1)
plt.ylabel("Estimation Error")
plt.grid(True, which="both", ls="dotted")
plt.legend((p[0], p0[0], p1[0], p4[0], p2[0], p3[0], p5[0], p6[0]), 
           ("Heisenberg limit", "noisy output", "rigorous mitigation", "Mooney et al. (t=1/10)", "Mooney et al. (t=1/100)", "proposed method", "SciPy", "SciPy with SGS"))
plt.show()

# %%
plt.clf()
p = plt.loglog( OracleCall_list, ErrorCramérRao_list)
p0 = plt.loglog( OracleCall_list, error_list, 'o', markersize=3)
p1 = plt.loglog( OracleCall_list, error_mit_list, '*', color='C4', markersize=6)
p2 = plt.loglog( OracleCall_list, error_mit_mooney100_list, 'x', color='C2', markersize=4)
p4 = plt.loglog( OracleCall_list, error_mit_mooney10_list, 'x', color='C5', markersize=4)
p3 = plt.loglog( OracleCall_list, error_mit_S_lm_0_list, 'v', color='C3', markersize=2)

plt.title("10qubit, p(0|1)=p(1|0)=0.01, b_max=π/100")
plt.xlim(OracleCall_list[0]*0.9, OracleCall_list[-1]*1.5)
plt.xlabel("Number of oracle calls")
plt.ylim(0.00000001, 1)
plt.ylabel("Estimation Error")
plt.grid(True, which="both", ls="dotted")
plt.legend((p[0], p0[0], p1[0], p4[0], p2[0], p3[0]), 
           ("Heisenberg limit", "noisy output", "rigorous mitigation", "Mooney et al. (t=1/10)", "Mooney et al. (t=1/100)", "proposed method"))
plt.show()

# %%
plt.clf()
p4 = plt.plot(ts_mooney10, color="C5")
p2 = plt.plot(ts_mooney100, color="C2")
p3 = plt.plot(ts_lm0_sgs, color="C3")
p5 = plt.plot(ts_scipy, color="C6")
p6 = plt.plot(ts_scipy_sgs, color="C7")
plt.title("10qubit, p(0|1)=p(1|0)=0.01, b_max=π/100")
plt.legend((p4[0], p2[0], p3[0], p5[0], p6[0]),
           ("Mooney et al. (t=1/10)", "Mooney et al. (t=1/100)", "proposed method", "SciPy", "SciPy with SGS"))
plt.show()
